# %%
import sys
sys.path.append('D:\\Tuan_Minh\\bds\\price_prediction_model')
from models import evaluate

evaluate.evaluateModel('Bình Chánh', 'Bán đất')
# Out:
# Train data length: 12
# Test data length: 4
# --------------------------------------------------------
#    post_type    area  price          street        ward    district  \
# 45   Bán đất   83.25   1.24  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 3    Bán đất   90.00   0.70  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 46   Bán đất  102.00   0.85  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 15   Bán đất  106.00   1.69  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 42   Bán đất  110.00   1.65  Đinh Đức Thiện  Bình Chánh  Bình Chánh
#
#    posted_date
# 45  2021-04-19
# 3   2021-05-16
# 46  2021-04-21
# 15  2021-03-21
# 42  2021-04-22
# --------------------------------------------------------
# Data length:  12
# Linear Regression Model:
# Linear model coefficient: [[0.64344394]]
# Linear model intercept: [7.95729731e-15]
# Linear model rmse: 0.7654932335125458
#
#
#
# Polynomial Regression with degree = 11
# Polynomial model coefficient: [[ 0.          0.11732041 -1.39962877  0.28503919  0.30330448  0.10987658
#    0.10268085  0.01098176  0.01215434 -0.00789823 -0.00503431 -0.00674878]]
# Polynomial model intercept: [0.3486501]
# Polynomial Model RMSE: 0.5558682595094228
#
#
#
# Linear Model score on train dataset:  0.41402010944650713
# Linear Model score on test dataset:  -0.4076955993967264
#
#
# Poly Model score on train dataset:  0.6910104780699651
# Poly Model score on test dataset:  -0.907946517224032
#
#
#
# Train data length: 16
# Test data length: 4
# --------------------------------------------------------
#    post_type   area    price            street       ward    district  \
# 3    Bán đất  100.0  4.00000  Đoàn Nguyễn Tuấn  Hưng Long  Bình Chánh
# 49   Bán đất  101.3  1.60054  Đoàn Nguyễn Tuấn  Hưng Long  Bình Chánh
# 43   Bán đất  102.4  1.60000  Đoàn Nguyễn Tuấn  Hưng Long  Bình Chánh
# 47   Bán đất  102.6  1.30302  Đoàn Nguyễn Tuấn  Hưng Long  Bình Chánh
# 48   Bán đất  105.0  2.60000  Đoàn Nguyễn Tuấn  Hưng Long  Bình Chánh
#
#    posted_date
# 3   2021-05-07
# 49  2021-05-02
# 43  2021-04-28
# 47  2021-05-02
# 48  2021-04-29
# --------------------------------------------------------
# Data length:  16
# Linear Regression Model:
# Linear model coefficient: [[0.64110229]]
# Linear model intercept: [2.11370281e-12]
# Linear model rmse: 0.7674554440446664
#
#
#
# Polynomial Regression with degree = 20
# Polynomial model coefficient: [[ 0.00000000e+00  7.48351409e-01 -9.32716517e-01 -2.68822402e-01
#    4.01483691e-01 -9.91347925e-02  8.81792566e-02 -1.89689289e-02
#    1.44692059e-02 -3.21391622e-03  2.06426047e-03 -5.62898895e-04
#    2.44431116e-04 -1.12466330e-04  1.51044791e-05 -2.66380179e-05
#   -4.27200524e-06 -7.21258975e-06 -2.59992999e-06 -2.09906106e-06
#   -9.77589195e-07]]
# Polynomial model intercept: [0.20132539]
# Polynomial Model RMSE: 0.6348115609490129
#
#
#
# Linear Model score on train dataset:  0.4110121414062039
# Linear Model score on test dataset:  0.427758978646965
#
#
# Poly Model score on train dataset:  0.5970142820854776
# Poly Model score on test dataset:  -0.9930799220692694
#
#
#
# Train data length: 15
# Test data length: 4
# --------------------------------------------------------
#    post_type   area  price            street     ward    district posted_date
# 21   Bán đất   80.5   1.20  Đoàn Nguyễn Tuấn  Quy Đức  Bình Chánh  2021-04-13
# 25   Bán đất   85.0   0.95  Đoàn Nguyễn Tuấn  Quy Đức  Bình Chánh  2021-04-27
# 1    Bán đất   85.7   1.35  Đoàn Nguyễn Tuấn  Quy Đức  Bình Chánh  2021-05-05
# 10   Bán đất   86.0   1.85  Đoàn Nguyễn Tuấn  Quy Đức  Bình Chánh  2021-04-26
# 13   Bán đất  100.0   1.85  Đoàn Nguyễn Tuấn  Quy Đức  Bình Chánh  2021-04-03
# --------------------------------------------------------
# Data length:  15
# Linear Regression Model:
# Linear model coefficient: [[0.75247307]]
# Linear model intercept: [5.9035847e-16]
# Linear model rmse: 0.65862301573729
#
#
#
# Polynomial Regression with degree = 15
# Polynomial model coefficient: [[ 0.          0.75262237  0.91659091  0.17115713 -0.38249803 -0.05491782
#   -0.16248749 -0.04543871 -0.04477935 -0.01764114 -0.00396759 -0.00311599
#    0.00604863  0.00174017  0.00623636  0.00244712]]
# Polynomial model intercept: [-0.00145565]
# Polynomial Model RMSE: 0.5252809988378482
#
#
#
# Linear Model score on train dataset:  0.5662157231411176
# Linear Model score on test dataset:  -0.6216084486308597
#
#
# Poly Model score on train dataset:  0.7240798722599125
# Poly Model score on test dataset:  0.06855073466167416
#
#
#
# Train data length: 47
# Test data length: 12
# --------------------------------------------------------
#    post_type  area  price           street        ward    district posted_date
# 43   Bán đất  80.4   2.45  Hoàng Phan Thái  Bình Chánh  Bình Chánh  2021-04-28
# 49   Bán đất  80.5   2.25  Hoàng Phan Thái  Bình Chánh  Bình Chánh  2021-04-28
# 57   Bán đất  80.7   2.30  Hoàng Phan Thái  Bình Chánh  Bình Chánh  2021-04-28
# 53   Bán đất  80.9   2.30  Hoàng Phan Thái  Bình Chánh  Bình Chánh  2021-04-28
# 51   Bán đất  81.0   2.30  Hoàng Phan Thái  Bình Chánh  Bình Chánh  2021-04-28
# --------------------------------------------------------
# Data length:  47
# Linear Regression Model:
# Linear model coefficient: [[0.66339538]]
# Linear model intercept: [-6.06908964e-14]
# Linear model rmse: 0.7482690489316005
#
#
#
# Polynomial Regression with degree = 26
# Polynomial model coefficient: [[ 0.00000000e+00  1.29567070e+00 -5.19285106e-02 -3.11321125e-01
#   -1.61857230e-03 -3.50381110e-02  1.88720612e-03 -2.31266370e-04
#    9.92029358e-04  1.15145823e-03  3.14051481e-04  4.11547178e-04
#    7.78677399e-05  1.04293697e-04  1.56267151e-05  2.20733166e-05
#    2.25254777e-06  3.95659412e-06  3.51423050e-08  5.42615743e-07
#   -1.38520488e-07  2.27376768e-08 -7.25588015e-08 -2.10423441e-08
#   -2.73789765e-08 -1.13238594e-08 -9.00161943e-09]]
# Polynomial model intercept: [-0.06447189]
# Polynomial Model RMSE: 0.6551819375203194
#
#
#
# Linear Model score on train dataset:  0.4400934304109979
# Linear Model score on test dataset:  0.4403078631335854
#
#
# Poly Model score on train dataset:  0.5707366287471203
# Poly Model score on test dataset:  0.6006475995172214
#
#
#
# Train data length: 12
# Test data length: 3
# --------------------------------------------------------
#    post_type  area  price      street       ward    district posted_date
# 1    Bán đất  70.0   2.20  Quốc Lộ 50  Phong Phú  Bình Chánh  2021-05-08
# 22   Bán đất  88.0   1.60  Quốc Lộ 50  Phong Phú  Bình Chánh  2021-03-19
# 29   Bán đất  90.0   1.89  Quốc Lộ 50  Phong Phú  Bình Chánh  2021-03-31
# 13   Bán đất  95.0   1.10  Quốc Lộ 50  Phong Phú  Bình Chánh  2021-03-12
# 2    Bán đất  98.0   2.20  Quốc Lộ 50  Phong Phú  Bình Chánh  2021-05-08
# --------------------------------------------------------
# Data length:  12
# Linear Regression Model:
# Linear model coefficient: [[-0.02705418]]
# Linear model intercept: [-9.29700235e-15]
# Linear model rmse: 0.9996339687110798
#
#
#
# Polynomial Regression with degree = 11
# Polynomial model coefficient: [[ 0.00000000e+00  1.00682374e-01 -1.05406516e+00 -2.14800400e-01
#    3.23778183e-03  4.22554329e-04  1.53699993e-02  3.45973990e-03
#    4.27973472e-03  9.28806219e-04  9.85691920e-04  2.06933079e-04]]
# Polynomial model intercept: [0.25814111]
# Polynomial Model RMSE: 0.8694270524575483
#
#
#
# Linear Model score on train dataset:  0.0007319285989361157
# Linear Model score on test dataset:  -0.02468608341103784
#
#
# Poly Model score on train dataset:  0.24409660045497994
# Poly Model score on test dataset:  -2.8106130990050384
#
#
#
# Train data length: 14
# Test data length: 4
# --------------------------------------------------------
#    post_type   area  price      street          ward    district posted_date
# 57   Bán đất   85.0  1.275  Tỉnh Lộ 10  Lê Minh Xuân  Bình Chánh  2021-04-13
# 22   Bán đất   90.0  1.350  Tỉnh Lộ 10  Lê Minh Xuân  Bình Chánh  2021-04-16
# 23   Bán đất  100.0  1.500  Tỉnh Lộ 10  Lê Minh Xuân  Bình Chánh  2021-04-16
# 54   Bán đất  105.0  1.580  Tỉnh Lộ 10  Lê Minh Xuân  Bình Chánh  2021-04-12
# 36   Bán đất  114.0  1.710  Tỉnh Lộ 10  Lê Minh Xuân  Bình Chánh  2021-03-19
# --------------------------------------------------------
# Data length:  14
# Linear Regression Model:
# Linear model coefficient: [[0.86040584]]
# Linear model intercept: [-6.84570417e-16]
# Linear model rmse: 0.5096094539550361
#
#
#
# Polynomial Regression with degree = 15
# Polynomial model coefficient: [[ 0.00000000e+00  1.19824119e+00 -7.66103037e-02 -4.03388616e-01
#   -1.62417256e-01 -2.98599186e-02  2.54811130e-03  2.39176841e-02
#    1.45393742e-02  1.21703108e-02  5.16755647e-03  3.07467652e-03
#    6.01855309e-04  1.00394983e-04 -4.53384559e-04 -4.04553974e-04]]
# Polynomial model intercept: [0.14083936]
# Polynomial Model RMSE: 0.41672263591787945
#
#
#
# Linear Model score on train dataset:  0.74029820443965
# Linear Model score on test dataset:  0.16684575067474205
#
#
# Poly Model score on train dataset:  0.8263422447136545
# Poly Model score on test dataset:  -0.02869885010020634
#
#
#
# Train data length: 19
# Test data length: 5
# --------------------------------------------------------
#    post_type  area  price      street          ward    district posted_date
# 17   Bán đất  80.0   1.20  Tỉnh Lộ 10  Phạm Văn Hai  Bình Chánh  2021-05-16
# 56   Bán đất  82.0   1.89  Tỉnh Lộ 10  Phạm Văn Hai  Bình Chánh  2021-04-19
# 23   Bán đất  84.0   1.30  Tỉnh Lộ 10  Phạm Văn Hai  Bình Chánh  2021-04-16
# 16   Bán đất  85.5   4.35  Tỉnh Lộ 10  Phạm Văn Hai  Bình Chánh  2021-05-16
# 2    Bán đất  90.0   1.35  Tỉnh Lộ 10  Phạm Văn Hai  Bình Chánh  2021-05-05
# --------------------------------------------------------
# Data length:  19
# Linear Regression Model:
# Linear model coefficient: [[0.6527693]]
# Linear model intercept: [-1.42021904e-15]
# Linear model rmse: 0.7575567616341005
#
#
#
# Polynomial Regression with degree = 18
# Polynomial model coefficient: [[ 0.00000000e+00  1.34157624e-01  3.72962056e-01  2.51147553e-01
#   -6.53947915e-02  6.03082604e-02 -1.31508040e-02  6.55168636e-03
#   -2.14294390e-03  4.97353167e-04 -3.47382158e-04  4.51351749e-06
#   -5.95897466e-05 -9.99108595e-06 -1.10832587e-05 -3.33127259e-06
#   -2.21722653e-06 -8.51301265e-07 -4.66235657e-07]]
# Polynomial model intercept: [-0.19725343]
# Polynomial Model RMSE: 0.695022940554908
#
#
#
# Linear Model score on train dataset:  0.4261077529024546
# Linear Model score on test dataset:  0.6082872360254934
#
#
# Poly Model score on train dataset:  0.5169431121024088
# Poly Model score on test dataset:  0.6118606017702435
#
#
#
# Train data length: 21
# Test data length: 6
# --------------------------------------------------------
#     post_type  area    price         street          ward    district  \
# 3     Bán đất  80.4  7.70232  Trần Văn Giàu  Lê Minh Xuân  Bình Chánh
# 200   Bán đất  81.0  1.22000  Trần Văn Giàu  Lê Minh Xuân  Bình Chánh
# 43    Bán đất  84.0  1.30000  Trần Văn Giàu  Lê Minh Xuân  Bình Chánh
# 210   Bán đất  85.0  1.27500  Trần Văn Giàu  Lê Minh Xuân  Bình Chánh
# 73    Bán đất  86.0  1.30000  Trần Văn Giàu  Lê Minh Xuân  Bình Chánh
#
#     posted_date
# 3    2021-05-02
# 200  2021-04-23
# 43   2021-04-16
# 210  2021-04-29
# 73   2021-04-16
# --------------------------------------------------------
# Data length:  21
# Linear Regression Model:
# Linear model coefficient: [[0.73296678]]
# Linear model intercept: [3.97960417e-16]
# Linear model rmse: 0.6802644376178842
#
#
#
# Polynomial Regression with degree = 20
# Polynomial model coefficient: [[ 0.00000000e+00  1.00734351e+00  1.17174628e-01  2.38043731e-01
#   -1.17941205e-01 -7.56670557e-02  3.92000954e-03 -4.60506842e-02
#    1.16325494e-02 -1.31498006e-02  4.76224269e-03 -2.90475528e-03
#    1.45033326e-03 -5.48699081e-04  3.95119343e-04 -8.67732291e-05
#    1.03001186e-04 -9.01055482e-06  2.65678534e-05  8.39360180e-07
#    6.90844749e-06]]
# Polynomial model intercept: [-0.2042328]
# Polynomial Model RMSE: 0.528496124900526
#
#
#
# Linear Model score on train dataset:  0.5372402949124235
# Linear Model score on test dataset:  0.9273132941140453
#
#
# Poly Model score on train dataset:  0.7206918459651275
# Poly Model score on test dataset:  0.8233121595667994
#
#
#
# Train data length: 32
# Test data length: 9
# --------------------------------------------------------
#     post_type  area  price         street          ward    district  \
# 300   Bán đất  82.0   1.23  Trần Văn Giàu  Phạm Văn Hai  Bình Chánh
# 64    Bán đất  83.0   2.10  Trần Văn Giàu  Phạm Văn Hai  Bình Chánh
# 62    Bán đất  84.0   1.50  Trần Văn Giàu  Phạm Văn Hai  Bình Chánh
# 28    Bán đất  85.0   1.30  Trần Văn Giàu  Phạm Văn Hai  Bình Chánh
# 78    Bán đất  86.0   1.30  Trần Văn Giàu  Phạm Văn Hai  Bình Chánh
#
#     posted_date
# 300  2021-04-23
# 64   2021-05-16
# 62   2021-05-16
# 28   2021-05-07
# 78   2021-05-16
# --------------------------------------------------------
# Data length:  32
# Linear Regression Model:
# Linear model coefficient: [[0.81859538]]
# Linear model intercept: [-3.33120962e-15]
# Linear model rmse: 0.5743706099360948
#
#
#
# Polynomial Regression with degree = 31
# Polynomial model coefficient: [[ 0.00000000e+00  8.20889321e-01 -1.79139649e-01 -4.11553541e-02
#    4.34424878e-02  1.94481476e-02  1.01939207e-02  3.66506619e-03
#    1.63774576e-03  3.62811777e-04  1.91565835e-04  1.16623642e-05
#    1.22798915e-05 -5.91158658e-06 -1.67490009e-06 -2.30991781e-06
#   -9.53302715e-07 -6.31064885e-07 -2.84848929e-07 -1.54808457e-07
#   -7.23427388e-08 -3.63482988e-08 -1.72214713e-08 -8.36455208e-09
#   -3.98183109e-09 -1.90598440e-09 -9.08155734e-10 -4.32115158e-10
#   -2.05795760e-10 -9.77047071e-11 -4.64943839e-11 -2.20596961e-11]]
# Polynomial model intercept: [0.07419167]
# Polynomial Model RMSE: 0.566173223134898
#
#
#
# Linear Model score on train dataset:  0.6700984024416383
# Linear Model score on test dataset:  0.7533767181292688
#
#
# Poly Model score on train dataset:  0.6794478814050409
# Poly Model score on test dataset:  0.7712911406741013
#
#
#
# Train data length: 27
# Test data length: 7
# --------------------------------------------------------
#    post_type  area  price    street        ward    district posted_date
# 5    Bán đất  50.0  0.399  Vĩnh Lộc  Vĩnh Lộc B  Bình Chánh  2021-05-05
# 76   Bán đất  52.0  0.380  Vĩnh Lộc  Vĩnh Lộc B  Bình Chánh  2021-04-11
# 21   Bán đất  56.0  0.410  Vĩnh Lộc  Vĩnh Lộc B  Bình Chánh  2021-02-25
# 90   Bán đất  60.0  0.420  Vĩnh Lộc  Vĩnh Lộc B  Bình Chánh  2021-05-01
# 87   Bán đất  63.0  0.560  Vĩnh Lộc  Vĩnh Lộc B  Bình Chánh  2021-05-01
# --------------------------------------------------------
# Data length:  27
# Linear Regression Model:
# Linear model coefficient: [[0.54706125]]
# Linear model intercept: [6.49495435e-15]
# Linear model rmse: 0.8370925816491913
#
#
#
# Polynomial Regression with degree = 22
# Polynomial model coefficient: [[ 0.00000000e+00  3.38108662e-01 -4.84386275e-01  2.91005977e-01
#    1.04264382e-01  1.98925131e-02  2.10202917e-02 -1.15083993e-03
#    2.16653859e-03 -6.43127520e-04  8.78167413e-05 -1.53730663e-04
#   -2.71063571e-05 -3.18619508e-05 -1.07550622e-05 -6.44732429e-06
#   -2.78368134e-06 -1.31638661e-06 -6.35044490e-07 -2.72670931e-07
#   -1.37578623e-07 -5.71087723e-08 -2.91230500e-08]]
# Polynomial model intercept: [0.27790235]
# Polynomial Model RMSE: 0.5918696717036382
#
#
#
# Linear Model score on train dataset:  0.2992760097478919
# Linear Model score on test dataset:  0.6104973605178536
#
#
# Poly Model score on train dataset:  0.6496902917174274
# Poly Model score on test dataset:  0.5582100488986707
#
#
#
# Train data length: 22
# Test data length: 6
# --------------------------------------------------------
#    post_type   area   price     street      ward    district posted_date
# 46   Bán đất   72.0  1.6992  Vườn Thơm  Bình Lợi  Bình Chánh  2021-05-02
# 33   Bán đất   88.0  1.7000  Vườn Thơm  Bình Lợi  Bình Chánh  2021-04-03
# 42   Bán đất   94.7  1.7500  Vườn Thơm  Bình Lợi  Bình Chánh  2021-04-28
# 36   Bán đất   96.3  1.6800  Vườn Thơm  Bình Lợi  Bình Chánh  2021-04-12
# 37   Bán đất  105.0  1.6000  Vườn Thơm  Bình Lợi  Bình Chánh  2021-04-22
# --------------------------------------------------------
# Data length:  22
# Linear Regression Model:
# Linear model coefficient: [[0.80640521]]
# Linear model intercept: [-3.22176425e-15]
# Linear model rmse: 0.5913633706580288
#
#
#
# Polynomial Regression with degree = 28
# Polynomial model coefficient: [[ 0.00000000e+00  1.24532147e+00 -5.44120915e-01 -2.32159179e-01
#   -8.73543870e-02 -9.32107210e-02  7.10320267e-04 -1.78610933e-02
#    1.14610913e-02  7.10972959e-04  7.38741226e-03  2.58796870e-03
#    3.40566361e-03  1.52433218e-03  1.30588210e-03  6.44264726e-04
#    4.25577268e-04  2.20848029e-04  1.11062238e-04  5.97027473e-05
#    1.60579291e-05  9.19848047e-06 -5.63167792e-06 -2.73116283e-06
#   -6.99789812e-06 -3.64797300e-06 -4.56529353e-06 -2.41663807e-06
#   -2.45419052e-06]]
# Polynomial model intercept: [0.36453924]
# Polynomial Model RMSE: 0.4721740536720275
#
#
#
# Linear Model score on train dataset:  0.6502893638439748
# Linear Model score on test dataset:  0.27389563998503863
#
#
# Poly Model score on train dataset:  0.7770516630389253
# Poly Model score on test dataset:  -2.6003242916880165

# %%
import sys
sys.path.append('D:\\Tuan_Minh\\bds\\price_prediction_model')
from models import evaluate

evaluate.evaluateModel('Bình Chánh', 'Bán nhà riêng')
# Out:
# Train data length: 16
# Test data length: 5
# --------------------------------------------------------
#         post_type  area  price          street        ward    district  \
# 8   Bán nhà riêng  50.0   0.70  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 2   Bán nhà riêng  56.0   0.67  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 16  Bán nhà riêng  64.0   0.90  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 7   Bán nhà riêng  68.0   1.40  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 54  Bán nhà riêng  70.0   1.44  Đinh Đức Thiện  Bình Chánh  Bình Chánh
#
#    posted_date
# 8   2021-05-11
# 2   2021-05-07
# 16  2021-05-16
# 7   2021-05-11
# 54  2021-04-16
# --------------------------------------------------------
# Data length:  16
# Linear Regression Model:
# Linear model coefficient: [[0.16491149]]
# Linear model intercept: [1.81627051e-17]
# Linear model rmse: 0.9863083701727744
#
#
#
# Polynomial Regression with degree = 15
# Polynomial model coefficient: [[ 0.00000000e+00 -1.19000442e-01 -1.32079177e+00 -2.54996967e-03
#   -1.31922653e-01  1.39293991e-02  1.17845459e-02  1.31495034e-03
#    7.46693546e-03  3.71415456e-05  2.31304543e-03  2.99459199e-05
#    6.48040677e-04  2.69313540e-05  1.80706851e-04  1.36493458e-05]]
# Polynomial model intercept: [1.07172513]
# Polynomial Model RMSE: 0.5191252291335429
#
#
#
# Linear Model score on train dataset:  0.02719579892712576
# Linear Model score on test dataset:  0.2661886509366407
#
#
# Poly Model score on train dataset:  0.7305089964770466
# Poly Model score on test dataset:  0.44702761609763086
