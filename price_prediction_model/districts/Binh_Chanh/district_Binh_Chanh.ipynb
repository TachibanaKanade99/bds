# %%
import sys
sys.path.append('D:\\Tuan_Minh\\bds\\price_prediction_model')
from models import evaluate

evaluate.evaluateModel('Bình Chánh', 'Bán đất')
# Out:
# ------------------------------
# Model Evaluation for Bán đất in Bình Chánh
# ------------------------------
#
#
# Train data length: 15
# Test data length: 4
# --------------------------------------------------------
#    post_type      area     price street          ward    district
# 5    Bán đất  4.394449  0.788457  An Hạ  Phạm Văn Hai  Bình Chánh
# 22   Bán đất  4.615121  0.916291  An Hạ  Phạm Văn Hai  Bình Chánh
# 25   Bán đất  4.873669  1.457898  An Hạ  Phạm Văn Hai  Bình Chánh
# 10   Bán đất  4.983607  1.386294  An Hạ  Phạm Văn Hai  Bình Chánh
# 8    Bán đất  5.117994  1.481605  An Hạ  Phạm Văn Hai  Bình Chánh
# --------------------------------------------------------
# Data length:  15
# Linear Regression Model:
# Linear model rmse: 0.19906625090350552
#
#
#
# Polynomial Regression with degree = 10
# Polynomial Model RMSE: 0.11251227224739851
# Linear Model score on train dataset:  0.8782612705342557
# Linear Model score on test dataset:  0.8689249975510331
# Poly Model score on train dataset:  0.9611104174352728
# Poly Model score on test dataset:  0.9194602170371544
#
#
#
#
# Train data length: 15
# Test data length: 4
# --------------------------------------------------------
#    post_type      area     price            street       ward    district
# 39   Bán đất  4.525044  0.896088  Đoàn Nguyễn Tuấn  Hưng Long  Bình Chánh
# 3    Bán đất  4.615121  0.955511  Đoàn Nguyễn Tuấn  Hưng Long  Bình Chánh
# 40   Bán đất  4.627910  0.955719  Đoàn Nguyễn Tuấn  Hưng Long  Bình Chánh
# 41   Bán đất  4.638605  0.955511  Đoàn Nguyễn Tuấn  Hưng Long  Bình Chánh
# 44   Bán đất  4.640537  0.834221  Đoàn Nguyễn Tuấn  Hưng Long  Bình Chánh
# --------------------------------------------------------
# Data length:  15
# Linear Regression Model:
# Linear model rmse: 0.09971052875800455
#
#
#
# Polynomial Regression with degree = 10
# Polynomial Model RMSE: 0.07177873026907008
# Linear Model score on train dataset:  0.5643440571372704
# Linear Model score on test dataset:  0.05566892281184199
# Poly Model score on train dataset:  0.7742368025383228
# Poly Model score on test dataset:  -66420372.91302505
#
#
# Train data length: 13
# Test data length: 4
# --------------------------------------------------------
#    post_type      area     price            street     ward    district
# 22   Bán đất  4.461300  1.047319  Đoàn Nguyễn Tuấn  Quy Đức  Bình Chánh
# 6    Bán đất  4.465908  1.047319  Đoàn Nguyễn Tuấn  Quy Đức  Bình Chánh
# 11   Bán đất  4.615121  1.047319  Đoàn Nguyễn Tuấn  Quy Đức  Bình Chánh
# 21   Bán đất  4.758749  1.223775  Đoàn Nguyễn Tuấn  Quy Đức  Bình Chánh
# 9    Bán đất  5.017280  1.294727  Đoàn Nguyễn Tuấn  Quy Đức  Bình Chánh
# --------------------------------------------------------
# Data length:  13
# Linear Regression Model:
# Linear model rmse: 0.12620263051423214
#
#
#
# Polynomial Regression with degree = 10
# Polynomial Model RMSE: 0.04778656217859665
# Linear Model score on train dataset:  0.1346066844896806
# Linear Model score on test dataset:  -0.10411911200119484
# Poly Model score on train dataset:  0.8759238532526361
# Poly Model score on test dataset:  -0.3990687660885588
#
#
# Train data length: 44
# Test data length: 11
# --------------------------------------------------------
#    post_type      area     price           street        ward    district
# 55   Bán đất  4.403054  1.193922  Hoàng Phan Thái  Bình Chánh  Bình Chánh
# 45   Bán đất  4.405499  1.193922  Hoàng Phan Thái  Bình Chánh  Bình Chánh
# 39   Bán đất  4.406719  1.193922  Hoàng Phan Thái  Bình Chánh  Bình Chánh
# 33   Bán đất  4.420045  1.435085  Hoàng Phan Thái  Bình Chánh  Bình Chánh
# 83   Bán đất  4.445001  1.322646  Hoàng Phan Thái  Bình Chánh  Bình Chánh
# --------------------------------------------------------
# Data length:  44
# Linear Regression Model:
# Linear model rmse: 0.2188776182843618
#
#
#
# Polynomial Regression with degree = 10
# Polynomial Model RMSE: 0.13747018535681277
# Linear Model score on train dataset:  0.7048094861589527
# Linear Model score on test dataset:  -1.2487482116892168
# Poly Model score on train dataset:  0.8835561047487279
# Poly Model score on test dataset:  -0.4475208701165996
#
#
#
#
#
#
# Train data length: 13
# Test data length: 4
# --------------------------------------------------------
#    post_type      area     price      street          ward    district
# 18   Bán đất  4.418841  0.832909  Tỉnh Lộ 10  Lê Minh Xuân  Bình Chánh
# 12   Bán đất  4.510860  0.854415  Tỉnh Lộ 10  Lê Minh Xuân  Bình Chánh
# 6    Bán đất  4.615121  0.936093  Tỉnh Lộ 10  Lê Minh Xuân  Bình Chánh
# 35   Bán đất  4.644391  1.558145  Tỉnh Lộ 10  Lê Minh Xuân  Bình Chánh
# 25   Bán đất  4.663439  0.955511  Tỉnh Lộ 10  Lê Minh Xuân  Bình Chánh
# --------------------------------------------------------
# Data length:  13
# Linear Regression Model:
# Linear model rmse: 0.21944345397719742
#
#
#
# Polynomial Regression with degree = 10
# Polynomial Model RMSE: 0.2057496271764043
# Linear Model score on train dataset:  0.6259370369347623
# Linear Model score on test dataset:  0.41969784373032537
# Poly Model score on train dataset:  0.6711653582281835
# Poly Model score on test dataset:  -1219752.2886065422
#
#
# Train data length: 14
# Test data length: 4
# --------------------------------------------------------
#    post_type      area     price      street          ward    district
# 25   Bán đất  4.418841  1.061257  Tỉnh Lộ 10  Phạm Văn Hai  Bình Chánh
# 5    Bán đất  4.442651  0.832909  Tỉnh Lộ 10  Phạm Văn Hai  Bình Chánh
# 98   Bán đất  4.510860  0.916291  Tỉnh Lộ 10  Phạm Văn Hai  Bình Chánh
# 2    Bán đất  4.595120  1.816452  Tỉnh Lộ 10  Phạm Văn Hai  Bình Chánh
# 3    Bán đất  4.663439  0.916291  Tỉnh Lộ 10  Phạm Văn Hai  Bình Chánh
# --------------------------------------------------------
# Data length:  14
# Linear Regression Model:
# Linear model rmse: 0.3435231528096968
#
#
#
# Polynomial Regression with degree = 8
# Polynomial Model RMSE: 0.27804857934513644
# Linear Model score on train dataset:  0.6663105379542089
# Linear Model score on test dataset:  0.24776815774487482
# Poly Model score on train dataset:  0.7813890927131389
# Poly Model score on test dataset:  0.24343623316512486
#
#
# Train data length: 19
# Test data length: 5
# --------------------------------------------------------
#     post_type      area     price         street          ward    district
# 194   Bán đất  4.399375  2.163590  Trần Văn Giàu  Lê Minh Xuân  Bình Chánh
# 77    Bán đất  4.406719  0.795252  Trần Văn Giàu  Lê Minh Xuân  Bình Chánh
# 13    Bán đất  4.454347  0.819780  Trần Văn Giàu  Lê Minh Xuân  Bình Chánh
# 53    Bán đất  4.465908  0.832909  Trần Văn Giàu  Lê Minh Xuân  Bình Chánh
# 39    Bán đất  4.510860  0.955511  Trần Văn Giàu  Lê Minh Xuân  Bình Chánh
# --------------------------------------------------------
# Data length:  19
# Linear Regression Model:
# Linear model rmse: 0.4130574429553441
#
#
#
# Polynomial Regression with degree = 8
# Polynomial Model RMSE: 0.2845964253533865
# Linear Model score on train dataset:  0.44998375254128375
# Linear Model score on test dataset:  -0.017833631807524508
# Poly Model score on train dataset:  0.7388960174426291
# Poly Model score on test dataset:  0.529087016982736
#
#
# Train data length: 28
# Test data length: 7
# --------------------------------------------------------
#     post_type      area     price         street          ward    district
# 120   Bán đất  4.418841  0.916291  Trần Văn Giàu  Phạm Văn Hai  Bình Chánh
# 2     Bán đất  4.442651  1.305626  Trần Văn Giàu  Phạm Văn Hai  Bình Chánh
# 7     Bán đất  4.454347  1.335001  Trần Văn Giàu  Phạm Văn Hai  Bình Chánh
# 24    Bán đất  4.510860  0.854415  Trần Văn Giàu  Phạm Văn Hai  Bình Chánh
# 51    Bán đất  4.564348  1.178655  Trần Văn Giàu  Phạm Văn Hai  Bình Chánh
# --------------------------------------------------------
# Data length:  28
# Linear Regression Model:
# Linear model rmse: 0.27625448054285345
#
#
#
# Polynomial Regression with degree = 10
# Polynomial Model RMSE: 0.21696159650550728
# Linear Model score on train dataset:  0.6360451041926312
# Linear Model score on test dataset:  0.025777252881513668
# Poly Model score on train dataset:  0.7755112195699327
# Poly Model score on test dataset:  -411761.5723705925
#
#
# Train data length: 25
# Test data length: 7
# --------------------------------------------------------
#    post_type      area     price    street        ward    district
# 2    Bán đất  3.970292  0.343590  Vĩnh Lộc  Vĩnh Lộc B  Bình Chánh
# 5    Bán đất  4.043051  0.343590  Vĩnh Lộc  Vĩnh Lộc B  Bình Chánh
# 72   Bán đất  4.110874  0.350657  Vĩnh Lộc  Vĩnh Lộc B  Bình Chánh
# 64   Bán đất  4.189655  0.405465  Vĩnh Lộc  Vĩnh Lộc B  Bình Chánh
# 46   Bán đất  4.290459  0.765468  Vĩnh Lộc  Vĩnh Lộc B  Bình Chánh
# --------------------------------------------------------
# Data length:  25
# Linear Regression Model:
# Linear model rmse: 0.3667214151403734
#
#
#
# Polynomial Regression with degree = 10
# Polynomial Model RMSE: 0.22389179726475997
# Linear Model score on train dataset:  0.3780254726982448
# Linear Model score on test dataset:  0.48646984131087123
# Poly Model score on train dataset:  0.7681663780848192
# Poly Model score on test dataset:  -23713105372.17243
#
#
#
#
# Train data length: 21
# Test data length: 6
# --------------------------------------------------------
#    post_type      area     price     street      ward    district
# 5    Bán đất  1.113501  1.871802  Vườn Thơm  Bình Lợi  Bình Chánh
# 49   Bán đất  4.290459  0.992955  Vườn Thơm  Bình Lợi  Bình Chánh
# 31   Bán đất  4.488636  0.993252  Vườn Thơm  Bình Lợi  Bình Chánh
# 35   Bán đất  4.577799  0.985817  Vườn Thơm  Bình Lợi  Bình Chánh
# 43   Bán đất  5.196838  1.178655  Vườn Thơm  Bình Lợi  Bình Chánh
# --------------------------------------------------------
# Data length:  21
# Linear Regression Model:
# Linear model rmse: 0.4778378311359385
#
#
#
# Polynomial Regression with degree = 10
# Polynomial Model RMSE: 0.3183180286567693
# Linear Model score on train dataset:  0.21165793669980082
# Linear Model score on test dataset:  0.6203960369542559
# Poly Model score on train dataset:  0.6501546452101936
# Poly Model score on test dataset:  0.8748818781749689

# %%
import sys
sys.path.append('D:\\Tuan_Minh\\bds\\price_prediction_model')
from models import evaluate

evaluate.evaluateModel('Bình Chánh', 'Bán nhà riêng')
# Out:
# ------------------------------
# Model Evaluation for Bán nhà riêng in Bình Chánh
# ------------------------------
#
#
# Train data length: 12
# Test data length: 4
# --------------------------------------------------------
#         post_type      area     price          street        ward    district
# 32  Bán nhà riêng  3.891820  0.636577  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 8   Bán nhà riêng  4.110874  0.788457  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 30  Bán nhà riêng  4.262680  0.891998  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 26  Bán nhà riêng  4.290459  0.916291  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# 15  Bán nhà riêng  4.330733  0.641854  Đinh Đức Thiện  Bình Chánh  Bình Chánh
# --------------------------------------------------------
# Data length:  12
# Linear Regression Model:
# Linear model rmse: 0.13065377260424996
#
#
#
# Polynomial Regression with degree = 7
# Polynomial Model RMSE: 0.0531511222618398
# Linear Model score on train dataset:  0.031302356080170846
# Linear Model score on test dataset:  -2.195241418581417
# Poly Model score on train dataset:  0.8396868261149946
# Poly Model score on test dataset:  -2.192225461591941
