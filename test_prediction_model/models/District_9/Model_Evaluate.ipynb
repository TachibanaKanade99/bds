# %%
import psycopg2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model


# convert to array:
# area = np.array(data['area'])
# price = np.array(data['price'])
# plt.scatter(area, price, marker='o')
# plt.show()

# Database Connection:
conn = psycopg2.connect(database="real_estate_data", user="postgres", password="361975Warcraft")
cur = conn.cursor()

def getData(post_type, street, ward, district, conn):
    # cur = conn.cursor()
    query = """
        SELECT post_type, area, price, street, ward, district
        FROM bds_realestatedata 
        WHERE
            post_type = '{post_type}' AND
            area IS NOT NULL AND
            price IS NOT NULL AND
            street = '{street}' AND
            ward = '{ward}' AND
            district = '{district}';
    """.format(post_type=post_type, street=street, ward=ward, district=district)
    # cur.execute(query)
    # data = cur.fetchall()
    data = pd.read_sql_query(query, con=conn)

    # data info
    print(data.head())
    print("Data length: ", len(data))
    return data

def splitData(data):
    # Selection few attributes
    attributes = list(
        [
            'area',
        ]
    )
    
    # Vector attributes of lands
    X = data[attributes]
    # Vector price of land
    Y = data['price']
    
    # Convert into arr:
    X = np.array(X)
    Y = np.array(Y)
    
    # plt.plot(Y)
    # plt.show()
    
    # Split data to training test and testing test
    # training data : testing data = 80 : 20
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
    
    return X_train, X_test, Y_train, Y_test

# Linear Regression Model:
def linearRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.LinearRegression()

    # Training process
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLinear Regression Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()
    
    score_trained = model.score(X_test, Y_test)

    return score_trained

# Lasso Model:
def lassoRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.Lasso(alpha=1.0)

    # Training process:
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLasso Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()

    # Evaluation the model:
    score_trained = model.score(X_test, Y_test)
    
    return score_trained


# Houses:
print("------------------------------")
print("Model Evaluation for Houses")
print("------------------------------")

cur.execute("SELECT post_type, street, ward, district, COUNT(id) FROM bds_realestatedata WHERE street IS NOT NULL AND ward IS NOT NULL AND district = %s AND post_type = %s GROUP BY post_type, street, ward, district HAVING COUNT(id) > %s;", ( '9', 'Bán nhà riêng', 10 ) )
item_lst = cur.fetchall()

for item in item_lst:
    post_type = item[0]
    street = item[1]
    ward = item[2]
    district = item[3]
    print("\n")
    data = getData(post_type, street, ward, district, conn)
    X_train, X_test, Y_train, Y_test = splitData(data)

    score = linearRegressionModel(X_train, Y_train, X_test, Y_test)
    print("Linear Regression training model score: ", score, "\n")

# Close connection:
cur.close()
conn.close()
# Out:
# ------------------------------
# Model Evaluation for Houses
# ------------------------------
#
#
#        post_type   area  price street             ward district
# 0  Bán nhà riêng   51.0   3.85    160  Tăng Nhơn Phú A        9
# 1  Bán nhà riêng   90.0   3.20    160  Tăng Nhơn Phú A        9
# 2  Bán nhà riêng  145.0   7.60    160  Tăng Nhơn Phú A        9
# 3  Bán nhà riêng   79.4   4.70    160  Tăng Nhơn Phú A        9
# 4  Bán nhà riêng  100.0   6.60    160  Tăng Nhơn Phú A        9
# Data length:  12
#
# Linear Regression Model:
# Linear Regression training model score:  0.29086922566331286
#
#
#
#        post_type  area  price          street             ward district
# 0  Bán nhà riêng  80.0   6.90  Đình Phong Phú  Tăng Nhơn Phú B        9
# 1  Bán nhà riêng  82.2   4.80  Đình Phong Phú  Tăng Nhơn Phú B        9
# 2  Bán nhà riêng  64.3   3.20  Đình Phong Phú  Tăng Nhơn Phú B        9
# 3  Bán nhà riêng  48.0   1.69  Đình Phong Phú  Tăng Nhơn Phú B        9
# 4  Bán nhà riêng  96.0   4.15  Đình Phong Phú  Tăng Nhơn Phú B        9
# Data length:  21
#
# Linear Regression Model:
# Linear Regression training model score:  -0.864945708439794
#
#
#
#        post_type   area  price       street          ward district
# 0  Bán nhà riêng  136.0  12.50  Đỗ Xuân Hợp  Phước Long B        9
# 1  Bán nhà riêng   90.0   2.70  Đỗ Xuân Hợp  Phước Long B        9
# 2  Bán nhà riêng   38.0   2.38  Đỗ Xuân Hợp  Phước Long B        9
# 3  Bán nhà riêng   59.0   1.32  Đỗ Xuân Hợp  Phước Long B        9
# 4  Bán nhà riêng  160.0  11.30  Đỗ Xuân Hợp  Phước Long B        9
# Data length:  20
#
# Linear Regression Model:
# Linear Regression training model score:  -2.105396725276144
#
#
#
#        post_type  area  price  street     ward district
# 0  Bán nhà riêng  32.0   1.10  Gò Cát  Phú Hữu        9
# 1  Bán nhà riêng  60.6   4.15  Gò Cát  Phú Hữu        9
# 2  Bán nhà riêng  62.4   4.90  Gò Cát  Phú Hữu        9
# 3  Bán nhà riêng  50.6   3.99  Gò Cát  Phú Hữu        9
# 4  Bán nhà riêng  55.9   5.50  Gò Cát  Phú Hữu        9
# Data length:  21
#
# Linear Regression Model:
# Linear Regression training model score:  0.6375870764431477
#
#
#
#        post_type   area  price       street      ward district
# 0  Bán nhà riêng  110.0   8.80  Lê Văn Việt  Hiệp Phú        9
# 1  Bán nhà riêng   47.0   1.63  Lê Văn Việt  Hiệp Phú        9
# 2  Bán nhà riêng  161.0  16.50  Lê Văn Việt  Hiệp Phú        9
# 3  Bán nhà riêng    3.0   1.25  Lê Văn Việt  Hiệp Phú        9
# 4  Bán nhà riêng   68.0   1.82  Lê Văn Việt  Hiệp Phú        9
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  0.8777601699328346
#
#
#
#        post_type    area  price            street         ward district
# 0  Bán nhà riêng   70.00   2.98  Nguyễn Duy Trinh  Long Trường        9
# 1  Bán nhà riêng   74.76   3.78  Nguyễn Duy Trinh  Long Trường        9
# 2  Bán nhà riêng  140.00   4.30  Nguyễn Duy Trinh  Long Trường        9
# 3  Bán nhà riêng   82.00   2.59  Nguyễn Duy Trinh  Long Trường        9
# 4  Bán nhà riêng  140.00   4.30  Nguyễn Duy Trinh  Long Trường        9
# Data length:  15
#
# Linear Regression Model:
# Linear Regression training model score:  -0.27453620393962064
#
#
#
#        post_type   area  price            street     ward district
# 0  Bán nhà riêng  452.0   24.0  Nguyễn Duy Trinh  Phú Hữu        9
# 1  Bán nhà riêng  160.0    3.8  Nguyễn Duy Trinh  Phú Hữu        9
# 2  Bán nhà riêng   55.0    4.2  Nguyễn Duy Trinh  Phú Hữu        9
# 3  Bán nhà riêng   50.0    2.9  Nguyễn Duy Trinh  Phú Hữu        9
# 4  Bán nhà riêng  186.0   12.0  Nguyễn Duy Trinh  Phú Hữu        9
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  -0.39372144761354955
#
#
#
#        post_type   area  price   street          ward district
# 0  Bán nhà riêng   80.0    7.6  Tây Hòa  Phước Long A        9
# 1  Bán nhà riêng   82.0    7.7  Tây Hòa  Phước Long A        9
# 2  Bán nhà riêng  219.0   16.4  Tây Hòa  Phước Long A        9
# 3  Bán nhà riêng  219.0   16.4  Tây Hòa  Phước Long A        9
# 4  Bán nhà riêng  220.0   16.5  Tây Hòa  Phước Long A        9
# Data length:  30
#
# Linear Regression Model:
# Linear Regression training model score:  0.6039976227560644
#
#
#
#        post_type    area  price      street         ward district
# 0  Bán nhà riêng    50.2   3.65  Trường Lưu  Long Trường        9
# 1  Bán nhà riêng    54.4   3.50  Trường Lưu  Long Trường        9
# 2  Bán nhà riêng    50.2   3.70  Trường Lưu  Long Trường        9
# 3  Bán nhà riêng    73.0   4.00  Trường Lưu  Long Trường        9
# 4  Bán nhà riêng  1100.0  36.00  Trường Lưu  Long Trường        9
# Data length:  12
#
# Linear Regression Model:
# Linear Regression training model score:  -14.80992735146777
#
#
#
#        post_type  area  price      street         ward district
# 0  Bán nhà riêng  53.0   4.25  Võ Văn Hát  Long Trường        9
# 1  Bán nhà riêng  63.0   3.68  Võ Văn Hát  Long Trường        9
# 2  Bán nhà riêng  64.0   3.60  Võ Văn Hát  Long Trường        9
# 3  Bán nhà riêng  54.0   4.25  Võ Văn Hát  Long Trường        9
# 4  Bán nhà riêng  53.0   3.90  Võ Văn Hát  Long Trường        9
# Data length:  13
#
# Linear Regression Model:
# Linear Regression training model score:  0.6583608589262933

# %%
import psycopg2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model


# convert to array:
# area = np.array(data['area'])
# price = np.array(data['price'])
# plt.scatter(area, price, marker='o')
# plt.show()

# Database Connection:
conn = psycopg2.connect(database="real_estate_data", user="postgres", password="361975Warcraft")
cur = conn.cursor()

def getData(post_type, street, ward, district, conn):
    # cur = conn.cursor()
    query = """
        SELECT post_type, area, price, street, ward, district
        FROM bds_realestatedata 
        WHERE
            post_type = '{post_type}' AND
            area IS NOT NULL AND
            price IS NOT NULL AND
            street = '{street}' AND
            ward = '{ward}' AND
            district = '{district}';
    """.format(post_type=post_type, street=street, ward=ward, district=district)
    # cur.execute(query)
    # data = cur.fetchall()
    data = pd.read_sql_query(query, con=conn)

    # data info
    print(data.head())
    print("Data length: ", len(data))
    return data

def splitData(data):
    # Selection few attributes
    attributes = list(
        [
            'area',
        ]
    )
    
    # Vector attributes of lands
    X = data[attributes]
    # Vector price of land
    Y = data['price']
    
    # Convert into arr:
    X = np.array(X)
    Y = np.array(Y)
    
    # plt.plot(Y)
    # plt.show()
    
    # Split data to training test and testing test
    # training data : testing data = 80 : 20
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
    
    return X_train, X_test, Y_train, Y_test

# Linear Regression Model:
def linearRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.LinearRegression()

    # Training process
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLinear Regression Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()
    
    score_trained = model.score(X_test, Y_test)

    return score_trained

# Lasso Model:
def lassoRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.Lasso(alpha=1.0)

    # Training process:
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLasso Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()

    # Evaluation the model:
    score_trained = model.score(X_test, Y_test)
    
    return score_trained

# Lands:
print("------------------------------")
print("Model Evaluation for Lands")
print("------------------------------")

cur.execute("SELECT post_type, street, ward, district, COUNT(id) FROM bds_realestatedata WHERE street IS NOT NULL AND ward IS NOT NULL AND district = %s AND post_type = %s GROUP BY post_type, street, ward, district HAVING COUNT(id) > %s;", ( '9', 'Bán đất', 10 ) )
item_lst = cur.fetchall()

for item in item_lst:
    post_type = item[0]
    street = item[1]
    ward = item[2]
    district = item[3]
    print("\n")
    data = getData(post_type, street, ward, district, conn)
    X_train, X_test, Y_train, Y_test = splitData(data)

    score = linearRegressionModel(X_train, Y_train, X_test, Y_test)
    print("Linear Regression training model score: ", score, "\n")

# Close connection:
cur.close()
conn.close()
# Out:
# ------------------------------
# Model Evaluation for Lands
# ------------------------------
#
#
#   post_type   area  price street             ward district
# 0   Bán đất  278.0    9.5    182  Tăng Nhơn Phú A        9
# 1   Bán đất  200.0    9.2    182  Tăng Nhơn Phú A        9
# 2   Bán đất  278.0    9.5    182  Tăng Nhơn Phú A        9
# 3   Bán đất  243.0    7.7    182  Tăng Nhơn Phú A        9
# 4   Bán đất  554.6   14.5    182  Tăng Nhơn Phú A        9
# Data length:  12
#
# Linear Regression Model:
# Linear Regression training model score:  0.42455722217409975
#
#
#
#   post_type  area  price street          ward district
# 0   Bán đất  77.4   5.00    339  Phước Long B        9
# 1   Bán đất  50.0   4.35    339  Phước Long B        9
# 2   Bán đất  75.0   4.60    339  Phước Long B        9
# 3   Bán đất  75.0   4.15    339  Phước Long B        9
# 4   Bán đất  75.0   4.20    339  Phước Long B        9
# Data length:  21
#
# Linear Regression Model:
# Linear Regression training model score:  0.769961248384291
#
#
#
#   post_type   area  price street           ward district
# 0   Bán đất  150.0  4.195    868  Long Thạnh Mỹ        9
# 1   Bán đất  150.0  4.195    868  Long Thạnh Mỹ        9
# 2   Bán đất  150.0  4.195    868  Long Thạnh Mỹ        9
# 3   Bán đất  150.0  4.195    868  Long Thạnh Mỹ        9
# 4   Bán đất  127.0  4.450    868  Long Thạnh Mỹ        9
# Data length:  15
#
# Linear Regression Model:
# Linear Regression training model score:  0.24276407394052413
#
#
#
#   post_type   area  price street     ward district
# 0   Bán đất  900.0  40.00    990  Phú Hữu        9
# 1   Bán đất   65.5   3.10    990  Phú Hữu        9
# 2   Bán đất  639.0  35.00    990  Phú Hữu        9
# 3   Bán đất  639.0  35.00    990  Phú Hữu        9
# 4   Bán đất   69.2   3.95    990  Phú Hữu        9
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  0.9678816417755736
#
#
#
#   post_type    area  price          street     ward district
# 0   Bán đất   128.0   6.40  Bưng Ông Thoàn  Phú Hữu        9
# 1   Bán đất    96.0   2.80  Bưng Ông Thoàn  Phú Hữu        9
# 2   Bán đất  4020.0  50.00  Bưng Ông Thoàn  Phú Hữu        9
# 3   Bán đất   234.0  10.50  Bưng Ông Thoàn  Phú Hữu        9
# 4   Bán đất   234.0  10.53  Bưng Ông Thoàn  Phú Hữu        9
# Data length:  86
#
# Linear Regression Model:
# Linear Regression training model score:  0.6542122268762195
#
#
#
#   post_type   area  price          street             ward district
# 0   Bán đất  168.0    9.5  Đình Phong Phú  Tăng Nhơn Phú B        9
# 1   Bán đất   99.0    5.5  Đình Phong Phú  Tăng Nhơn Phú B        9
# 2   Bán đất   99.0    5.5  Đình Phong Phú  Tăng Nhơn Phú B        9
# 3   Bán đất  525.0   30.0  Đình Phong Phú  Tăng Nhơn Phú B        9
# 4   Bán đất   60.0    1.5  Đình Phong Phú  Tăng Nhơn Phú B        9
# Data length:  16
#
# Linear Regression Model:
# Linear Regression training model score:  0.7207122388051149
#
#
#
#   post_type    area  price       street          ward district
# 0   Bán đất    80.0    3.5  Đỗ Xuân Hợp  Phước Long B        9
# 1   Bán đất    60.0    1.8  Đỗ Xuân Hợp  Phước Long B        9
# 2   Bán đất   100.0    1.9  Đỗ Xuân Hợp  Phước Long B        9
# 3   Bán đất   100.0    3.0  Đỗ Xuân Hợp  Phước Long B        9
# 4   Bán đất  1400.0   58.0  Đỗ Xuân Hợp  Phước Long B        9
# Data length:  49
#
# Linear Regression Model:
# Linear Regression training model score:  -0.2338452270735707
#
#
#
#   post_type   area  price          street          ward district
# 0   Bán đất   87.0  13.50  Dương Đình Hội  Phước Long B        9
# 1   Bán đất   87.0  13.50  Dương Đình Hội  Phước Long B        9
# 2   Bán đất  100.0   2.25  Dương Đình Hội  Phước Long B        9
# 3   Bán đất   60.0   4.30  Dương Đình Hội  Phước Long B        9
# 4   Bán đất   90.0  13.50  Dương Đình Hội  Phước Long B        9
# Data length:  16
#
# Linear Regression Model:
# Linear Regression training model score:  -0.0987642234004571
#
#
#
#   post_type    area   price  street     ward district
# 0   Bán đất   126.0   5.922  Gò Cát  Phú Hữu        9
# 1   Bán đất   370.0   9.000  Gò Cát  Phú Hữu        9
# 2   Bán đất    50.9   2.950  Gò Cát  Phú Hữu        9
# 3   Bán đất    85.0   4.675  Gò Cát  Phú Hữu        9
# 4   Bán đất  1800.0  16.000  Gò Cát  Phú Hữu        9
# Data length:  39
#
# Linear Regression Model:
# Linear Regression training model score:  0.20984639335852762
#
#
#
#   post_type   area  price      street          ward district
# 0   Bán đất  145.7  10.20  Hồ Bá Phấn  Phước Long A        9
# 1   Bán đất   56.0   5.50  Hồ Bá Phấn  Phước Long A        9
# 2   Bán đất   95.0   1.09  Hồ Bá Phấn  Phước Long A        9
# 3   Bán đất   62.0   5.35  Hồ Bá Phấn  Phước Long A        9
# 4   Bán đất   61.7   5.40  Hồ Bá Phấn  Phước Long A        9
# Data length:  14
#
# Linear Regression Model:
# Linear Regression training model score:  -17.964824330415315
#
#
#
#   post_type   area  price         street       ward district
# 0   Bán đất  100.0    1.2  Hoàng Hữu Nam  Long Bình        9
# 1   Bán đất   90.0    1.6  Hoàng Hữu Nam  Long Bình        9
# 2   Bán đất  120.0    1.2  Hoàng Hữu Nam  Long Bình        9
# 3   Bán đất   76.0    3.0  Hoàng Hữu Nam  Long Bình        9
# 4   Bán đất  100.0    1.5  Hoàng Hữu Nam  Long Bình        9
# Data length:  19
#
# Linear Regression Model:
# Linear Regression training model score:  0.5963355535821999
#
#
#
#   post_type    area  price         street           ward district
# 0   Bán đất    75.0    1.8  Hoàng Hữu Nam  Long Thạnh Mỹ        9
# 1   Bán đất   100.0    1.8  Hoàng Hữu Nam  Long Thạnh Mỹ        9
# 2   Bán đất  1266.4   40.0  Hoàng Hữu Nam  Long Thạnh Mỹ        9
# 3   Bán đất    52.0    4.1  Hoàng Hữu Nam  Long Thạnh Mỹ        9
# 4   Bán đất    80.0    2.8  Hoàng Hữu Nam  Long Thạnh Mỹ        9
# Data length:  52
#
# Linear Regression Model:
# Linear Regression training model score:  -2.684916814308981
#
#
#
#   post_type   area  price         street     ward district
# 0   Bán đất   50.8    1.6  Hoàng Hữu Nam  Tân Phú        9
# 1   Bán đất   75.0    2.3  Hoàng Hữu Nam  Tân Phú        9
# 2   Bán đất  100.0    2.5  Hoàng Hữu Nam  Tân Phú        9
# 3   Bán đất  100.0    5.5  Hoàng Hữu Nam  Tân Phú        9
# 4   Bán đất  100.0    2.5  Hoàng Hữu Nam  Tân Phú        9
# Data length:  26
#
# Linear Regression Model:
# Linear Regression training model score:  0.6132173630688476
#
#
#
#   post_type   area  price       street         ward district
# 0   Bán đất   62.4   3.90  Lã Xuân Oai  Long Trường        9
# 1   Bán đất   62.4   3.90  Lã Xuân Oai  Long Trường        9
# 2   Bán đất   62.4   3.88  Lã Xuân Oai  Long Trường        9
# 3   Bán đất   50.0   3.60  Lã Xuân Oai  Long Trường        9
# 4   Bán đất  826.0  34.60  Lã Xuân Oai  Long Trường        9
# Data length:  26
#
# Linear Regression Model:
# Linear Regression training model score:  -0.054578802300813356
#
#
#
#   post_type    area  price       street             ward district
# 0   Bán đất  400.82  43.00  Lã Xuân Oai  Tăng Nhơn Phú A        9
# 1   Bán đất  380.00  14.06  Lã Xuân Oai  Tăng Nhơn Phú A        9
# 2   Bán đất  440.00  21.00  Lã Xuân Oai  Tăng Nhơn Phú A        9
# 3   Bán đất  186.00  21.00  Lã Xuân Oai  Tăng Nhơn Phú A        9
# 4   Bán đất  432.00  17.28  Lã Xuân Oai  Tăng Nhơn Phú A        9
# Data length:  16
#
# Linear Regression Model:
# Linear Regression training model score:  0.4133933864862457
#
#
#
#   post_type   area  price         street             ward district
# 0   Bán đất   60.5   4.00  Làng Tăng Phú  Tăng Nhơn Phú A        9
# 1   Bán đất   93.0   5.13  Làng Tăng Phú  Tăng Nhơn Phú A        9
# 2   Bán đất   98.0   5.40  Làng Tăng Phú  Tăng Nhơn Phú A        9
# 3   Bán đất   98.3   5.40  Làng Tăng Phú  Tăng Nhơn Phú A        9
# 4   Bán đất  380.0  15.50  Làng Tăng Phú  Tăng Nhơn Phú A        9
# Data length:  14
#
# Linear Regression Model:
# Linear Regression training model score:  -1.9924816189976315
#
#
#
#   post_type   area  price       street             ward district
# 0   Bán đất  100.0   1.80  Lê Văn Việt  Tăng Nhơn Phú A        9
# 1   Bán đất  100.0   2.50  Lê Văn Việt  Tăng Nhơn Phú A        9
# 2   Bán đất   85.0   1.25  Lê Văn Việt  Tăng Nhơn Phú A        9
# 3   Bán đất   80.0   2.30  Lê Văn Việt  Tăng Nhơn Phú A        9
# 4   Bán đất   70.0   2.10  Lê Văn Việt  Tăng Nhơn Phú A        9
# Data length:  15
#
# Linear Regression Model:
# Linear Regression training model score:  -0.23590313932706564
#
#
#
#   post_type   area  price       street     ward district
# 0   Bán đất   70.0    1.7  Liên Phường  Phú Hữu        9
# 1   Bán đất  382.0   57.3  Liên Phường  Phú Hữu        9
# 2   Bán đất  105.0    2.4  Liên Phường  Phú Hữu        9
# 3   Bán đất  100.0    3.2  Liên Phường  Phú Hữu        9
# 4   Bán đất  100.0    1.8  Liên Phường  Phú Hữu        9
# Data length:  22
#
# Linear Regression Model:
# Linear Regression training model score:  0.7260353769176455
#
#
#
#   post_type   area  price       street          ward district
# 0   Bán đất   90.0    2.5  Liên Phường  Phước Long B        9
# 1   Bán đất  100.0    2.5  Liên Phường  Phước Long B        9
# 2   Bán đất  100.0    3.2  Liên Phường  Phước Long B        9
# 3   Bán đất   52.0    3.9  Liên Phường  Phước Long B        9
# 4   Bán đất  100.0    1.2  Liên Phường  Phước Long B        9
# Data length:  67
#
# Linear Regression Model:
# Linear Regression training model score:  0.783272273611736
#
#
#
#   post_type     area  price street          ward district
# 0   Bán đất    999.0   24.5  Lò Lu  Trường Thạnh        9
# 1   Bán đất  50000.0  100.0  Lò Lu  Trường Thạnh        9
# 2   Bán đất     72.0    1.5  Lò Lu  Trường Thạnh        9
# 3   Bán đất   1000.0   24.0  Lò Lu  Trường Thạnh        9
# 4   Bán đất     80.0    1.8  Lò Lu  Trường Thạnh        9
# Data length:  33
#
# Linear Regression Model:
# Linear Regression training model score:  -25.24647630727847
#
#
#
#   post_type    area  price      street        ward district
# 0   Bán đất    55.6   2.68  Long Phước  Long Phước        9
# 1   Bán đất    50.6   2.10  Long Phước  Long Phước        9
# 2   Bán đất    52.4   2.46  Long Phước  Long Phước        9
# 3   Bán đất  3500.0  38.50  Long Phước  Long Phước        9
# 4   Bán đất   250.0   5.49  Long Phước  Long Phước        9
# Data length:  64
#
# Linear Regression Model:
# Linear Regression training model score:  0.789788622411916
#
#
#
#   post_type    area   price      street        ward district
# 0   Bán đất    90.0   1.470  Long Thuận  Long Phước        9
# 1   Bán đất    85.0   1.230  Long Thuận  Long Phước        9
# 2   Bán đất  1882.0  65.870  Long Thuận  Long Phước        9
# 3   Bán đất  1696.0  20.352  Long Thuận  Long Phước        9
# 4   Bán đất   809.0  15.000  Long Thuận  Long Phước        9
# Data length:  42
#
# Linear Regression Model:
# Linear Regression training model score:  -4.691828818792984
#
#
#
#   post_type    area  price      street          ward district
# 0   Bán đất   100.0    2.5  Long Thuận  Trường Thạnh        9
# 1   Bán đất  1100.0   37.0  Long Thuận  Trường Thạnh        9
# 2   Bán đất   100.0    2.2  Long Thuận  Trường Thạnh        9
# 3   Bán đất   928.0   50.0  Long Thuận  Trường Thạnh        9
# 4   Bán đất    81.0    3.5  Long Thuận  Trường Thạnh        9
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  0.7289105622896476
#
#
#
#   post_type   area   price     street             ward district
# 0   Bán đất  105.0   1.900  Man Thiện  Tăng Nhơn Phú A        9
# 1   Bán đất   96.0  10.500  Man Thiện  Tăng Nhơn Phú A        9
# 2   Bán đất   96.0  10.500  Man Thiện  Tăng Nhơn Phú A        9
# 3   Bán đất   95.8  10.500  Man Thiện  Tăng Nhơn Phú A        9
# 4   Bán đất  119.0   7.854  Man Thiện  Tăng Nhơn Phú A        9
# Data length:  29
#
# Linear Regression Model:
# Linear Regression training model score:  -5.836355721843596
#
#
#
#   post_type   area  price            street         ward district
# 0   Bán đất   83.4   3.35  Nguyễn Duy Trinh  Long Trường        9
# 1   Bán đất   83.4   3.35  Nguyễn Duy Trinh  Long Trường        9
# 2   Bán đất  113.8   4.35  Nguyễn Duy Trinh  Long Trường        9
# 3   Bán đất  300.0  13.00  Nguyễn Duy Trinh  Long Trường        9
# 4   Bán đất  113.8   4.35  Nguyễn Duy Trinh  Long Trường        9
# Data length:  38
#
# Linear Regression Model:
# Linear Regression training model score:  -3.349587913674344
#
#
#
#   post_type    area  price            street     ward district
# 0   Bán đất   225.0    7.8  Nguyễn Duy Trinh  Phú Hữu        9
# 1   Bán đất   260.7   17.0  Nguyễn Duy Trinh  Phú Hữu        9
# 2   Bán đất   170.0   19.9  Nguyễn Duy Trinh  Phú Hữu        9
# 3   Bán đất  1196.0   35.0  Nguyễn Duy Trinh  Phú Hữu        9
# 4   Bán đất   110.0    6.6  Nguyễn Duy Trinh  Phú Hữu        9
# Data length:  31
#
# Linear Regression Model:
# Linear Regression training model score:  -2.389188950910926
#
#
#
#   post_type   area  price            street          ward district
# 0   Bán đất   57.0   2.75  Nguyễn Duy Trinh  Trường Thạnh        9
# 1   Bán đất   54.1   3.00  Nguyễn Duy Trinh  Trường Thạnh        9
# 2   Bán đất  100.0   3.90  Nguyễn Duy Trinh  Trường Thạnh        9
# 3   Bán đất  245.0  11.50  Nguyễn Duy Trinh  Trường Thạnh        9
# 4   Bán đất   54.1   3.00  Nguyễn Duy Trinh  Trường Thạnh        9
# Data length:  12
#
# Linear Regression Model:
# Linear Regression training model score:  -8.45778736063936
#
#
#
#   post_type   area  price           street           ward district
# 0   Bán đất  526.1   20.5  Nguyễn Văn Tăng  Long Thạnh Mỹ        9
# 1   Bán đất   87.5    3.6  Nguyễn Văn Tăng  Long Thạnh Mỹ        9
# 2   Bán đất  120.0   14.2  Nguyễn Văn Tăng  Long Thạnh Mỹ        9
# 3   Bán đất   80.0    1.8  Nguyễn Văn Tăng  Long Thạnh Mỹ        9
# 4   Bán đất  119.6   14.2  Nguyễn Văn Tăng  Long Thạnh Mỹ        9
# Data length:  16
#
# Linear Regression Model:
# Linear Regression training model score:  0.6964976959791506
#
#
#
#   post_type   area  price       street       ward district
# 0   Bán đất   80.0   2.40  Nguyễn Xiển  Long Bình        9
# 1   Bán đất   64.0   2.24  Nguyễn Xiển  Long Bình        9
# 2   Bán đất   65.0   2.95  Nguyễn Xiển  Long Bình        9
# 3   Bán đất   72.0   3.00  Nguyễn Xiển  Long Bình        9
# 4   Bán đất  206.7  13.00  Nguyễn Xiển  Long Bình        9
# Data length:  21
#
# Linear Regression Model:
# Linear Regression training model score:  0.7498294121260038
#
#
#
#   post_type   area  price       street           ward district
# 0   Bán đất   80.0   3.40  Nguyễn Xiển  Long Thạnh Mỹ        9
# 1   Bán đất   72.0   3.50  Nguyễn Xiển  Long Thạnh Mỹ        9
# 2   Bán đất  127.0   4.45  Nguyễn Xiển  Long Thạnh Mỹ        9
# 3   Bán đất  107.0   3.20  Nguyễn Xiển  Long Thạnh Mỹ        9
# 4   Bán đất   84.0   2.80  Nguyễn Xiển  Long Thạnh Mỹ        9
# Data length:  66
#
# Linear Regression Model:
# Linear Regression training model score:  0.3114173818527728
#
#
#
#   post_type    area  price       street       ward district
# 0   Bán đất    82.0   2.55  Phước Thiện  Long Bình        9
# 1   Bán đất   100.0   3.40  Phước Thiện  Long Bình        9
# 2   Bán đất    64.6   7.90  Phước Thiện  Long Bình        9
# 3   Bán đất    65.0   7.90  Phước Thiện  Long Bình        9
# 4   Bán đất  7000.0  80.50  Phước Thiện  Long Bình        9
# Data length:  20
#
# Linear Regression Model:
# Linear Regression training model score:  -0.42469820546915527
#
#
#
#   post_type    area  price       street           ward district
# 0   Bán đất  100.00  12.50  Phước Thiện  Long Thạnh Mỹ        9
# 1   Bán đất   51.97   2.57  Phước Thiện  Long Thạnh Mỹ        9
# 2   Bán đất  100.00   2.50  Phước Thiện  Long Thạnh Mỹ        9
# 3   Bán đất   96.00   2.30  Phước Thiện  Long Thạnh Mỹ        9
# 4   Bán đất  100.00  12.00  Phước Thiện  Long Thạnh Mỹ        9
# Data length:  18
#
# Linear Regression Model:
# Linear Regression training model score:  -0.2860426932410707
#
#
#
#   post_type    area   price street        ward district
# 0   Bán đất  1683.0  13.464   Số 5  Long Phước        9
# 1   Bán đất   830.0   9.000   Số 5  Long Phước        9
# 2   Bán đất  1500.0  18.000   Số 5  Long Phước        9
# 3   Bán đất  5275.0  75.000   Số 5  Long Phước        9
# 4   Bán đất  2614.0  31.368   Số 5  Long Phước        9
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  -1.0416873619846867
#
#
#
#   post_type    area  price street        ward district
# 0   Bán đất    62.0   2.20   Số 8  Long Phước        9
# 1   Bán đất  1360.0  20.40   Số 8  Long Phước        9
# 2   Bán đất    80.0   2.27   Số 8  Long Phước        9
# 3   Bán đất  1900.0  42.75   Số 8  Long Phước        9
# 4   Bán đất   115.6   5.78   Số 8  Long Phước        9
# Data length:  22
#
# Linear Regression Model:
# Linear Regression training model score:  0.05103776093898815
#
#
#
#   post_type   area  price  street          ward district
# 0   Bán đất  152.0  5.928  Tam Đa  Trường Thạnh        9
# 1   Bán đất  100.0  1.600  Tam Đa  Trường Thạnh        9
# 2   Bán đất  124.4  3.500  Tam Đa  Trường Thạnh        9
# 3   Bán đất   80.0  1.700  Tam Đa  Trường Thạnh        9
# 4   Bán đất   91.1  3.170  Tam Đa  Trường Thạnh        9
# Data length:  22
#
# Linear Regression Model:
# Linear Regression training model score:  0.5342783292300333
#
#
#
#   post_type   area  price         street          ward district
# 0   Bán đất  350.0   29.5  Tăng Nhơn Phú  Phước Long B        9
# 1   Bán đất  350.0   29.5  Tăng Nhơn Phú  Phước Long B        9
# 2   Bán đất  350.0   29.5  Tăng Nhơn Phú  Phước Long B        9
# 3   Bán đất  350.0   29.0  Tăng Nhơn Phú  Phước Long B        9
# 4   Bán đất  350.0   29.0  Tăng Nhơn Phú  Phước Long B        9
# Data length:  15
#
# Linear Regression Model:
# Linear Regression training model score:  0.9686300905239444
#
#
#
#   post_type   area  price   street          ward district
# 0   Bán đất  175.0   8.75  Tây Hòa  Phước Long A        9
# 1   Bán đất   60.3   4.30  Tây Hòa  Phước Long A        9
# 2   Bán đất  420.0  19.00  Tây Hòa  Phước Long A        9
# 3   Bán đất  420.0  21.00  Tây Hòa  Phước Long A        9
# 4   Bán đất   80.0   1.80  Tây Hòa  Phước Long A        9
# Data length:  18
#
# Linear Regression Model:
# Linear Regression training model score:  0.9264019675676858
#
#
#
#   post_type  area  price      street         ward district
# 0   Bán đất  89.0   3.25  Trường Lưu  Long Trường        9
# 1   Bán đất  52.8   3.00  Trường Lưu  Long Trường        9
# 2   Bán đất  70.0   1.80  Trường Lưu  Long Trường        9
# 3   Bán đất  81.0   3.50  Trường Lưu  Long Trường        9
# 4   Bán đất  88.2   4.15  Trường Lưu  Long Trường        9
# Data length:  49
#
# Linear Regression Model:
# Linear Regression training model score:  0.7838057488130028
#
#
#
#   post_type   area  price            street      ward district
# 0   Bán đất   72.0    6.5  Trương Văn Thành  Hiệp Phú        9
# 1   Bán đất  121.0   12.7  Trương Văn Thành  Hiệp Phú        9
# 2   Bán đất   55.0    5.0  Trương Văn Thành  Hiệp Phú        9
# 3   Bán đất   72.0    6.5  Trương Văn Thành  Hiệp Phú        9
# 4   Bán đất   60.0    1.2  Trương Văn Thành  Hiệp Phú        9
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  0.7442129761297622
#
#
#
#   post_type    area  price      street         ward district
# 0   Bán đất    74.8    4.0  Võ Văn Hát  Long Trường        9
# 1   Bán đất   235.0   20.0  Võ Văn Hát  Long Trường        9
# 2   Bán đất    75.0    4.0  Võ Văn Hát  Long Trường        9
# 3   Bán đất    66.0    3.5  Võ Văn Hát  Long Trường        9
# 4   Bán đất  5000.0   50.0  Võ Văn Hát  Long Trường        9
# Data length:  57
#
# Linear Regression Model:
# Linear Regression training model score:  0.5070113481712071
