# %%
import psycopg2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model


# convert to array:
# area = np.array(data['area'])
# price = np.array(data['price'])
# plt.scatter(area, price, marker='o')
# plt.show()

# Database Connection:
conn = psycopg2.connect(database="real_estate_data", user="postgres", password="361975Warcraft")
cur = conn.cursor()

def getData(post_type, street, ward, district, conn):
    # cur = conn.cursor()
    query = """
        SELECT post_type, area, price, street, ward, district
        FROM bds_realestatedata 
        WHERE
            post_type = '{post_type}' AND
            area IS NOT NULL AND
            price IS NOT NULL AND
            street = '{street}' AND
            ward = '{ward}' AND
            district = '{district}';
    """.format(post_type=post_type, street=street, ward=ward, district=district)
    # cur.execute(query)
    # data = cur.fetchall()
    data = pd.read_sql_query(query, con=conn)

    # data info
    print(data.head())
    print("Data length: ", len(data))
    return data

def splitData(data):
    # Selection few attributes
    attributes = list(
        [
            'area',
        ]
    )
    
    # Vector attributes of lands
    X = data[attributes]
    # Vector price of land
    Y = data['price']
    
    # Convert into arr:
    X = np.array(X)
    Y = np.array(Y)
    
    # plt.plot(Y)
    # plt.show()
    
    # Split data to training test and testing test
    # training data : testing data = 80 : 20
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
    
    return X_train, X_test, Y_train, Y_test

# Linear Regression Model:
def linearRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.LinearRegression()

    # Training process
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLinear Regression Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()
    
    score_trained = model.score(X_test, Y_test)

    return score_trained

# Lasso Model:
def lassoRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.Lasso(alpha=1.0)

    # Training process:
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLasso Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()

    # Evaluation the model:
    score_trained = model.score(X_test, Y_test)
    
    return score_trained


# Houses:
print("------------------------------")
print("Model Evaluation for Houses")
print("------------------------------")

cur.execute("SELECT post_type, street, ward, district, COUNT(id) FROM bds_realestatedata WHERE street IS NOT NULL AND ward IS NOT NULL AND district = %s AND post_type = %s GROUP BY post_type, street, ward, district HAVING COUNT(id) > %s;", ( 'Tân Phú', 'Bán nhà riêng', 10 ) )
item_lst = cur.fetchall()

for item in item_lst:
    post_type = item[0]
    street = item[1]
    ward = item[2]
    district = item[3]
    print("\n")
    data = getData(post_type, street, ward, district, conn)
    X_train, X_test, Y_train, Y_test = splitData(data)

    score = linearRegressionModel(X_train, Y_train, X_test, Y_test)
    print("Linear Regression training model score: ", score, "\n")

# Close connection:
cur.close()
conn.close()
# Out:
# ------------------------------
# Model Evaluation for Houses
# ------------------------------
#
#
#        post_type   area  price            street    ward district
# 0  Bán nhà riêng   79.0   8.60  Bờ Bao Tân Thắng  Sơn Kỳ  Tân Phú
# 1  Bán nhà riêng  172.0  28.50  Bờ Bao Tân Thắng  Sơn Kỳ  Tân Phú
# 2  Bán nhà riêng   56.0   6.30  Bờ Bao Tân Thắng  Sơn Kỳ  Tân Phú
# 3  Bán nhà riêng   56.0   6.25  Bờ Bao Tân Thắng  Sơn Kỳ  Tân Phú
# 4  Bán nhà riêng  172.0  28.50  Bờ Bao Tân Thắng  Sơn Kỳ  Tân Phú
# Data length:  24
#
# Linear Regression Model:
# Linear Regression training model score:  0.9310955180240499
#
#
#
#        post_type  area  price    street    ward district
# 0  Bán nhà riêng  44.0   1.87  Đỗ Nhuận  Sơn Kỳ  Tân Phú
# 1  Bán nhà riêng  44.0   1.86  Đỗ Nhuận  Sơn Kỳ  Tân Phú
# 2  Bán nhà riêng  71.0   6.00  Đỗ Nhuận  Sơn Kỳ  Tân Phú
# 3  Bán nhà riêng  72.0   6.00  Đỗ Nhuận  Sơn Kỳ  Tân Phú
# 4  Bán nhà riêng  54.0   5.30  Đỗ Nhuận  Sơn Kỳ  Tân Phú
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  0.7548909293709486
#
#
#
#        post_type  area  price         street     ward district
# 0  Bán nhà riêng  77.0    6.7  Đỗ Thừa Luông  Tân Quý  Tân Phú
# 1  Bán nhà riêng  48.0    4.1  Đỗ Thừa Luông  Tân Quý  Tân Phú
# 2  Bán nhà riêng  48.0    4.2  Đỗ Thừa Luông  Tân Quý  Tân Phú
# 3  Bán nhà riêng  52.0    6.2  Đỗ Thừa Luông  Tân Quý  Tân Phú
# 4  Bán nhà riêng  51.0    6.2  Đỗ Thừa Luông  Tân Quý  Tân Phú
# Data length:  12
#
# Linear Regression Model:
# Linear Regression training model score:  -61.93783682683834
#
#
#
#        post_type   area  price  street     ward district
# 0  Bán nhà riêng   85.0    6.8  Gò Dầu  Tân Quý  Tân Phú
# 1  Bán nhà riêng  150.0   15.0  Gò Dầu  Tân Quý  Tân Phú
# 2  Bán nhà riêng   80.0    7.8  Gò Dầu  Tân Quý  Tân Phú
# 3  Bán nhà riêng   76.0    7.5  Gò Dầu  Tân Quý  Tân Phú
# 4  Bán nhà riêng   50.7    6.3  Gò Dầu  Tân Quý  Tân Phú
# Data length:  72
#
# Linear Regression Model:
# Linear Regression training model score:  0.8260856246003462
#
#
#
#        post_type   area  price  street         ward district
# 0  Bán nhà riêng  112.0   13.5  Gò Dầu  Tân Sơn Nhì  Tân Phú
# 1  Bán nhà riêng  115.0   13.5  Gò Dầu  Tân Sơn Nhì  Tân Phú
# 2  Bán nhà riêng   98.0   12.5  Gò Dầu  Tân Sơn Nhì  Tân Phú
# 3  Bán nhà riêng   64.0    6.2  Gò Dầu  Tân Sơn Nhì  Tân Phú
# 4  Bán nhà riêng   80.0    6.5  Gò Dầu  Tân Sơn Nhì  Tân Phú
# Data length:  13
#
# Linear Regression Model:
# Linear Regression training model score:  -11.545194305701632
#
#
#
#        post_type   area  price     street       ward district
# 0  Bán nhà riêng   36.0   3.50  Hồ Đắc Di  Tây Thạnh  Tân Phú
# 1  Bán nhà riêng   32.0   2.63  Hồ Đắc Di  Tây Thạnh  Tân Phú
# 2  Bán nhà riêng  120.0   2.63  Hồ Đắc Di  Tây Thạnh  Tân Phú
# 3  Bán nhà riêng   36.0   3.50  Hồ Đắc Di  Tây Thạnh  Tân Phú
# 4  Bán nhà riêng   97.0  11.50  Hồ Đắc Di  Tây Thạnh  Tân Phú
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  -254.91057761759194
#
#
#
#        post_type  area  price    street      ward district
# 0  Bán nhà riêng  60.0  13.90  Hòa Bình  Hiệp Tân  Tân Phú
# 1  Bán nhà riêng  56.0   5.60  Hòa Bình  Hiệp Tân  Tân Phú
# 2  Bán nhà riêng  53.2   5.60  Hòa Bình  Hiệp Tân  Tân Phú
# 3  Bán nhà riêng  48.0   6.60  Hòa Bình  Hiệp Tân  Tân Phú
# 4  Bán nhà riêng  37.0   3.45  Hòa Bình  Hiệp Tân  Tân Phú
# Data length:  17
#
# Linear Regression Model:
# Linear Regression training model score:  0.09365052971710142
#
#
#
#        post_type  area  price           street       ward district
# 0  Bán nhà riêng  35.0    4.2  Huỳnh Thiện Lộc  Hòa Thạnh  Tân Phú
# 1  Bán nhà riêng  65.0    7.7  Huỳnh Thiện Lộc  Hòa Thạnh  Tân Phú
# 2  Bán nhà riêng  76.0    8.5  Huỳnh Thiện Lộc  Hòa Thạnh  Tân Phú
# 3  Bán nhà riêng  46.0    4.2  Huỳnh Thiện Lộc  Hòa Thạnh  Tân Phú
# 4  Bán nhà riêng  64.0    6.9  Huỳnh Thiện Lộc  Hòa Thạnh  Tân Phú
# Data length:  21
#
# Linear Regression Model:
# Linear Regression training model score:  0.8379514361263194
#
#
#
#        post_type   area  price       street       ward district
# 0  Bán nhà riêng   41.0   4.40  Khuông Việt  Phú Trung  Tân Phú
# 1  Bán nhà riêng   57.0   7.50  Khuông Việt  Phú Trung  Tân Phú
# 2  Bán nhà riêng  110.0   8.00  Khuông Việt  Phú Trung  Tân Phú
# 3  Bán nhà riêng   36.0   1.75  Khuông Việt  Phú Trung  Tân Phú
# 4  Bán nhà riêng   41.0   1.78  Khuông Việt  Phú Trung  Tân Phú
# Data length:  16
#
# Linear Regression Model:
# Linear Regression training model score:  -10.164870664463923
#
#
#
#        post_type   area  price        street    ward district
# 0  Bán nhà riêng   36.0    3.3  Lê Trọng Tấn  Sơn Kỳ  Tân Phú
# 1  Bán nhà riêng   76.0    6.3  Lê Trọng Tấn  Sơn Kỳ  Tân Phú
# 2  Bán nhà riêng   56.0    6.3  Lê Trọng Tấn  Sơn Kỳ  Tân Phú
# 3  Bán nhà riêng  166.0   14.5  Lê Trọng Tấn  Sơn Kỳ  Tân Phú
# 4  Bán nhà riêng  126.0    5.3  Lê Trọng Tấn  Sơn Kỳ  Tân Phú
# Data length:  13
#
# Linear Regression Model:
# Linear Regression training model score:  0.7033254337521921
#
#
#
#        post_type  area  price        street       ward district
# 0  Bán nhà riêng  33.0   2.90  Lê Trọng Tấn  Tây Thạnh  Tân Phú
# 3  Bán nhà riêng  280.0  26.50  Tây Thạnh  Tây Thạnh  Tân Phú
# 4  Bán nhà riêng  105.0  10.99  Tây Thạnh  Tây Thạnh  Tân Phú
# Data length:  23
#
# Linear Regression Model:
# Linear Regression training model score:  0.6067186664063147
#
#
#
#        post_type  area  price     street       ward district
# 0  Bán nhà riêng  40.0   2.35  Thạch Lam  Phú Thạnh  Tân Phú
# 1  Bán nhà riêng  44.0   1.78  Thạch Lam  Phú Thạnh  Tân Phú
# 2  Bán nhà riêng  44.0   1.78  Thạch Lam  Phú Thạnh  Tân Phú
# 3  Bán nhà riêng  64.0   7.50  Thạch Lam  Phú Thạnh  Tân Phú
# 4  Bán nhà riêng  64.0   6.50  Thạch Lam  Phú Thạnh  Tân Phú
# Data length:  13
#
# Linear Regression Model:
# Linear Regression training model score:  0.7017271078446603
#
#
#
#        post_type  area  price          street       ward district
# 0  Bán nhà riêng  40.0   4.75  Thoại Ngọc Hầu  Phú Thạnh  Tân Phú
# 1  Bán nhà riêng  97.0   7.65  Thoại Ngọc Hầu  Phú Thạnh  Tân Phú
# 2  Bán nhà riêng  75.6   6.00  Thoại Ngọc Hầu  Phú Thạnh  Tân Phú
# 3  Bán nhà riêng  78.0   7.10  Thoại Ngọc Hầu  Phú Thạnh  Tân Phú
# 4  Bán nhà riêng  50.0   3.50  Thoại Ngọc Hầu  Phú Thạnh  Tân Phú
# Data length:  37
#
# Linear Regression Model:
# Linear Regression training model score:  0.8646847249157327
#
#
#
#        post_type  area  price   street      ward district
# 0  Bán nhà riêng  54.0   7.90  Tô Hiệu  Hiệp Tân  Tân Phú
# 1  Bán nhà riêng  68.0   7.60  Tô Hiệu  Hiệp Tân  Tân Phú
# 2  Bán nhà riêng  58.0   5.80  Tô Hiệu  Hiệp Tân  Tân Phú
# 3  Bán nhà riêng  56.0   7.65  Tô Hiệu  Hiệp Tân  Tân Phú
# 4  Bán nhà riêng   4.0   6.00  Tô Hiệu  Hiệp Tân  Tân Phú
# Data length:  18
#
# Linear Regression Model:
# Linear Regression training model score:  -0.739370753599486
#
#
#
#        post_type  area  price            street       ward district
# 0  Bán nhà riêng  60.4    5.2  Trịnh Đình Trọng  Phú Trung  Tân Phú
# 1  Bán nhà riêng  37.5    3.8  Trịnh Đình Trọng  Phú Trung  Tân Phú
# 2  Bán nhà riêng  56.0    7.5  Trịnh Đình Trọng  Phú Trung  Tân Phú
# 3  Bán nhà riêng  68.0    5.2  Trịnh Đình Trọng  Phú Trung  Tân Phú
# 4  Bán nhà riêng   4.0    5.3  Trịnh Đình Trọng  Phú Trung  Tân Phú
# Data length:  13
#
# Linear Regression Model:
# Linear Regression training model score:  0.07564830752321816
#
#
#
#        post_type  area  price    street         ward district
# 0  Bán nhà riêng  32.0   4.25  Vườn Lài  Phú Thọ Hòa  Tân Phú
# 1  Bán nhà riêng  52.0   6.70  Vườn Lài  Phú Thọ Hòa  Tân Phú
# 2  Bán nhà riêng  64.0   5.90  Vườn Lài  Phú Thọ Hòa  Tân Phú
# 3  Bán nhà riêng  57.0   6.50  Vườn Lài  Phú Thọ Hòa  Tân Phú
# 4  Bán nhà riêng  79.8   7.90  Vườn Lài  Phú Thọ Hòa  Tân Phú
# Data length:  60
#
# Linear Regression Model:
# Linear Regression training model score:  0.36657868803208504
#
#
#
#        post_type   area  price    street       ward district
# 0  Bán nhà riêng   61.0   6.30  Vườn Lài  Tân Thành  Tân Phú
# 1  Bán nhà riêng   56.0   6.25  Vườn Lài  Tân Thành  Tân Phú
# 2  Bán nhà riêng   64.0   6.50  Vườn Lài  Tân Thành  Tân Phú
# 3  Bán nhà riêng   63.6   6.80  Vườn Lài  Tân Thành  Tân Phú
# 4  Bán nhà riêng  240.0  21.00  Vườn Lài  Tân Thành  Tân Phú
# Data length:  37
#
# Linear Regression Model:
# Linear Regression training model score:  0.7002808329544732

# %%
import psycopg2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model


# convert to array:
# area = np.array(data['area'])
# price = np.array(data['price'])
# plt.scatter(area, price, marker='o')
# plt.show()

# Database Connection:
conn = psycopg2.connect(database="real_estate_data", user="postgres", password="361975Warcraft")
cur = conn.cursor()

def getData(post_type, street, ward, district, conn):
    # cur = conn.cursor()
    query = """
        SELECT post_type, area, price, street, ward, district
        FROM bds_realestatedata 
        WHERE
            post_type = '{post_type}' AND
            area IS NOT NULL AND
            price IS NOT NULL AND
            street = '{street}' AND
            ward = '{ward}' AND
            district = '{district}';
    """.format(post_type=post_type, street=street, ward=ward, district=district)
    # cur.execute(query)
    # data = cur.fetchall()
    data = pd.read_sql_query(query, con=conn)

    # data info
    print(data.head())
    print("Data length: ", len(data))
    return data

def splitData(data):
    # Selection few attributes
    attributes = list(
        [
            'area',
        ]
    )
    
    # Vector attributes of lands
    X = data[attributes]
    # Vector price of land
    Y = data['price']
    
    # Convert into arr:
    X = np.array(X)
    Y = np.array(Y)
    
    # plt.plot(Y)
    # plt.show()
    
    # Split data to training test and testing test
    # training data : testing data = 80 : 20
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
    
    return X_train, X_test, Y_train, Y_test

# Linear Regression Model:
def linearRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.LinearRegression()

    # Training process
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLinear Regression Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()
    
    score_trained = model.score(X_test, Y_test)

    return score_trained

# Lasso Model:
def lassoRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.Lasso(alpha=1.0)

    # Training process:
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLasso Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()

    # Evaluation the model:
    score_trained = model.score(X_test, Y_test)
    
    return score_trained

# Lands:
print("------------------------------")
print("Model Evaluation for Lands")
print("------------------------------")

cur.execute("SELECT post_type, street, ward, district, COUNT(id) FROM bds_realestatedata WHERE street IS NOT NULL AND ward IS NOT NULL AND district = %s AND post_type = %s GROUP BY post_type, street, ward, district HAVING COUNT(id) > %s;", ( 'Tân Phú', 'Bán đất', 10 ) )
item_lst = cur.fetchall()

for item in item_lst:
    post_type = item[0]
    street = item[1]
    ward = item[2]
    district = item[3]
    print("\n")
    data = getData(post_type, street, ward, district, conn)
    X_train, X_test, Y_train, Y_test = splitData(data)

    score = linearRegressionModel(X_train, Y_train, X_test, Y_test)
    print("Linear Regression training model score: ", score, "\n")

# Close connection:
cur.close()
conn.close()
# Out:
# ------------------------------
# Model Evaluation for Lands
# ------------------------------
#
#
#   post_type   area  price        street       ward district
# 0   Bán đất   90.0    1.7  Lũy Bán Bích  Hòa Thạnh  Tân Phú
# 1   Bán đất  178.0   15.0  Lũy Bán Bích  Hòa Thạnh  Tân Phú
# 2   Bán đất   90.0    1.9  Lũy Bán Bích  Hòa Thạnh  Tân Phú
# 3   Bán đất  100.0    1.6  Lũy Bán Bích  Hòa Thạnh  Tân Phú
# 4   Bán đất   80.0    1.8  Lũy Bán Bích  Hòa Thạnh  Tân Phú
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  -5.328517761277593
#
#
#
#   post_type  area  price           street       ward district
# 0   Bán đất  82.0   2.55  Nguyễn Hữu Tiến  Tây Thạnh  Tân Phú
# 1   Bán đất  80.0   1.60  Nguyễn Hữu Tiến  Tây Thạnh  Tân Phú
# 2   Bán đất  90.0   3.20  Nguyễn Hữu Tiến  Tây Thạnh  Tân Phú
# 3   Bán đất  98.6   9.00  Nguyễn Hữu Tiến  Tây Thạnh  Tân Phú
# 4   Bán đất  80.0   2.40  Nguyễn Hữu Tiến  Tây Thạnh  Tân Phú
# Data length:  15
#
# Linear Regression Model:
# Linear Regression training model score:  0.027405556001776188
#
#
#
#   post_type   area  price           street         ward district
# 0   Bán đất   80.0    5.3  Nguyễn Văn Săng  Tân Sơn Nhì  Tân Phú
# 1   Bán đất   90.0    3.9  Nguyễn Văn Săng  Tân Sơn Nhì  Tân Phú
# 2   Bán đất   80.0    4.3  Nguyễn Văn Săng  Tân Sơn Nhì  Tân Phú
# 3   Bán đất  120.0    4.5  Nguyễn Văn Săng  Tân Sơn Nhì  Tân Phú
# 4   Bán đất  120.0    6.5  Nguyễn Văn Săng  Tân Sơn Nhì  Tân Phú
# Data length:  13
#
# Linear Regression Model:
# Linear Regression training model score:  -13.331568383040858
#
#
#
#   post_type   area  price    street         ward district
# 0   Bán đất   63.6   2.95  Vườn Lài  Phú Thọ Hòa  Tân Phú
# 1   Bán đất   63.6   3.40  Vườn Lài  Phú Thọ Hòa  Tân Phú
# 2   Bán đất   65.0   3.50  Vườn Lài  Phú Thọ Hòa  Tân Phú
# 3   Bán đất   56.0   4.80  Vườn Lài  Phú Thọ Hòa  Tân Phú
# 4   Bán đất  256.0  30.00  Vườn Lài  Phú Thọ Hòa  Tân Phú
# Data length:  13
#
# Linear Regression Model:
# Linear Regression training model score:  -0.33308347803012506
