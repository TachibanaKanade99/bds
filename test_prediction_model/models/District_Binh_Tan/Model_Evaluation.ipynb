# %%
import psycopg2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model


# convert to array:
# area = np.array(data['area'])
# price = np.array(data['price'])
# plt.scatter(area, price, marker='o')
# plt.show()

# Database Connection:
conn = psycopg2.connect(database="real_estate_data", user="postgres", password="361975Warcraft")
cur = conn.cursor()

def getData(post_type, street, ward, district, conn):
    # cur = conn.cursor()
    query = """
        SELECT post_type, area, price, street, ward, district
        FROM bds_realestatedata 
        WHERE
            post_type = '{post_type}' AND
            area IS NOT NULL AND
            price IS NOT NULL AND
            street = '{street}' AND
            ward = '{ward}' AND
            district = '{district}';
    """.format(post_type=post_type, street=street, ward=ward, district=district)
    # cur.execute(query)
    # data = cur.fetchall()
    data = pd.read_sql_query(query, con=conn)

    # data info
    print(data.head())
    print("Data length: ", len(data))
    return data

def splitData(data):
    # Selection few attributes
    attributes = list(
        [
            'area',
        ]
    )
    
    # Vector attributes of lands
    X = data[attributes]
    # Vector price of land
    Y = data['price']
    
    # Convert into arr:
    X = np.array(X)
    Y = np.array(Y)
    
    # plt.plot(Y)
    # plt.show()
    
    # Split data to training test and testing test
    # training data : testing data = 80 : 20
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
    
    return X_train, X_test, Y_train, Y_test

# Linear Regression Model:
def linearRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.LinearRegression()

    # Training process
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLinear Regression Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()
    
    score_trained = model.score(X_test, Y_test)

    return score_trained

# Lasso Model:
def lassoRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.Lasso(alpha=1.0)

    # Training process:
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLasso Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()

    # Evaluation the model:
    score_trained = model.score(X_test, Y_test)
    
    return score_trained


# Houses:
print("------------------------------")
print("Model Evaluation for Houses")
print("------------------------------")

cur.execute("SELECT post_type, street, ward, district, COUNT(id) FROM bds_realestatedata WHERE street IS NOT NULL AND ward IS NOT NULL AND district = %s AND post_type = %s GROUP BY post_type, street, ward, district HAVING COUNT(id) > %s;", ( 'Bình Tân', 'Bán nhà riêng', 10 ) )
item_lst = cur.fetchall()

for item in item_lst:
    post_type = item[0]
    street = item[1]
    ward = item[2]
    district = item[3]
    print("\n")
    data = getData(post_type, street, ward, district, conn)
    X_train, X_test, Y_train, Y_test = splitData(data)

    score = linearRegressionModel(X_train, Y_train, X_test, Y_test)
    print("Linear Regression training model score: ", score, "\n")

# Close connection:
cur.close()
conn.close()
# Out:
# ------------------------------
# Model Evaluation for Houses
# ------------------------------
#
#
#        post_type   area  price      street             ward  district
# 0  Bán nhà riêng   60.0   3.40  Bình Thành  Bình Hưng Hòa B  Bình Tân
# 1  Bán nhà riêng   60.0   5.30  Bình Thành  Bình Hưng Hòa B  Bình Tân
# 2  Bán nhà riêng  220.0   3.50  Bình Thành  Bình Hưng Hòa B  Bình Tân
# 3  Bán nhà riêng   60.0   3.55  Bình Thành  Bình Hưng Hòa B  Bình Tân
# 4  Bán nhà riêng   60.0   4.35  Bình Thành  Bình Hưng Hòa B  Bình Tân
# Data length:  35
#
# Linear Regression Model:
# Linear Regression training model score:  -0.1417744694808043
#
#
#
#        post_type  area  price       street    ward  district
# 0  Bán nhà riêng  42.0   3.95  Bùi Tư Toàn  An Lạc  Bình Tân
# 1  Bán nhà riêng  56.0   5.30  Bùi Tư Toàn  An Lạc  Bình Tân
# 2  Bán nhà riêng  41.1   3.55  Bùi Tư Toàn  An Lạc  Bình Tân
# 3  Bán nhà riêng  80.0   4.75  Bùi Tư Toàn  An Lạc  Bình Tân
# 4  Bán nhà riêng  64.0   6.20  Bùi Tư Toàn  An Lạc  Bình Tân
# Data length:  20
#
# Linear Regression Model:
# Linear Regression training model score:  -2.067495236199268
#
#
#
#        post_type  area  price      street           ward  district
# 0  Bán nhà riêng  56.0    5.5  Hương lộ 2  Bình Trị Đông  Bình Tân
# 1  Bán nhà riêng  80.0    4.8  Hương lộ 2  Bình Trị Đông  Bình Tân
# 2  Bán nhà riêng  88.0    5.5  Hương lộ 2  Bình Trị Đông  Bình Tân
# 3  Bán nhà riêng  64.0    5.8  Hương lộ 2  Bình Trị Đông  Bình Tân
# 4  Bán nhà riêng  55.0    3.5  Hương lộ 2  Bình Trị Đông  Bình Tân
# Data length:  21
#
# Linear Regression Model:
# Linear Regression training model score:  -0.022301568513891423
#
#
#
#        post_type  area  price      street             ward  district
# 0  Bán nhà riêng  48.0    3.4  Hương lộ 2  Bình Trị Đông A  Bình Tân
# 1  Bán nhà riêng  48.0    3.6  Hương lộ 2  Bình Trị Đông A  Bình Tân
# 2  Bán nhà riêng  56.0    5.6  Hương lộ 2  Bình Trị Đông A  Bình Tân
# 3  Bán nhà riêng  40.0    3.4  Hương lộ 2  Bình Trị Đông A  Bình Tân
# 4  Bán nhà riêng  56.0    4.5  Hương lộ 2  Bình Trị Đông A  Bình Tân
# Data length:  59
#
# Linear Regression Model:
# Linear Regression training model score:  0.14872993167020843
#
#
#
#        post_type  area  price       street             ward  district
# 0  Bán nhà riêng  60.0   5.45  Lê Văn Quới  Bình Hưng Hòa A  Bình Tân
# 1  Bán nhà riêng  64.0   6.30  Lê Văn Quới  Bình Hưng Hòa A  Bình Tân
# 2  Bán nhà riêng  47.8   4.20  Lê Văn Quới  Bình Hưng Hòa A  Bình Tân
# 3  Bán nhà riêng  74.0   6.30  Lê Văn Quới  Bình Hưng Hòa A  Bình Tân
# 4  Bán nhà riêng  48.0   5.50  Lê Văn Quới  Bình Hưng Hòa A  Bình Tân
# Data length:  42
#
# Linear Regression Model:
# Linear Regression training model score:  0.28288914079156724
#
#
#
#        post_type   area  price       street             ward  district
# 0  Bán nhà riêng   96.0   6.20  Lê Văn Quới  Bình Trị Đông A  Bình Tân
# 1  Bán nhà riêng   72.0   5.70  Lê Văn Quới  Bình Trị Đông A  Bình Tân
# 2  Bán nhà riêng   56.0   4.35  Lê Văn Quới  Bình Trị Đông A  Bình Tân
# 3  Bán nhà riêng   57.0   3.68  Lê Văn Quới  Bình Trị Đông A  Bình Tân
# 4  Bán nhà riêng  280.0   5.50  Lê Văn Quới  Bình Trị Đông A  Bình Tân
# Data length:  21
#
# Linear Regression Model:
# Linear Regression training model score:  -1.7972139697657896
#
#
#
#        post_type  area  price        street             ward  district
# 0  Bán nhà riêng  48.0   2.35  Liên khu 4-5  Bình Hưng Hòa B  Bình Tân
# 1  Bán nhà riêng   2.0   1.12  Liên khu 4-5  Bình Hưng Hòa B  Bình Tân
# 2  Bán nhà riêng  72.0   3.00  Liên khu 4-5  Bình Hưng Hòa B  Bình Tân
# 3  Bán nhà riêng  72.0   3.80  Liên khu 4-5  Bình Hưng Hòa B  Bình Tân
# 4  Bán nhà riêng  88.0   5.40  Liên khu 4-5  Bình Hưng Hòa B  Bình Tân
# Data length:  51
#
# Linear Regression Model:
# Linear Regression training model score:  0.22959190491274606
#
#
#
#        post_type  area  price        street             ward  district
# 0  Bán nhà riêng  56.0   4.35  Liên Khu 5-6  Bình Hưng Hòa B  Bình Tân
# 1  Bán nhà riêng   2.0   1.65  Liên Khu 5-6  Bình Hưng Hòa B  Bình Tân
# 2  Bán nhà riêng  66.0   3.45  Liên Khu 5-6  Bình Hưng Hòa B  Bình Tân
# 3  Bán nhà riêng   4.0   2.50  Liên Khu 5-6  Bình Hưng Hòa B  Bình Tân
# 4  Bán nhà riêng  72.0   3.90  Liên Khu 5-6  Bình Hưng Hòa B  Bình Tân
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  -0.11739630593350414
#
#
#
#        post_type  area  price street             ward  district
# 0  Bán nhà riêng  68.0  6.400  Mã Lò  Bình Trị Đông A  Bình Tân
# 1  Bán nhà riêng  24.0  2.095  Mã Lò  Bình Trị Đông A  Bình Tân
# 2  Bán nhà riêng  56.0  5.500  Mã Lò  Bình Trị Đông A  Bình Tân
# 3  Bán nhà riêng  60.0  5.650  Mã Lò  Bình Trị Đông A  Bình Tân
# 4  Bán nhà riêng  65.0  4.600  Mã Lò  Bình Trị Đông A  Bình Tân
# Data length:  14
#
# Linear Regression Model:
# Linear Regression training model score:  -1.8055068041925404
#
#
#
#        post_type   area  price         street             ward  district
# 0  Bán nhà riêng   40.0   1.95  Nguyễn Thị Tú  Bình Hưng Hòa B  Bình Tân
# 1  Bán nhà riêng   60.0   4.17  Nguyễn Thị Tú  Bình Hưng Hòa B  Bình Tân
# 2  Bán nhà riêng  165.0   3.50  Nguyễn Thị Tú  Bình Hưng Hòa B  Bình Tân
# 3  Bán nhà riêng   55.0   3.48  Nguyễn Thị Tú  Bình Hưng Hòa B  Bình Tân
# 4  Bán nhà riêng   52.0   4.40  Nguyễn Thị Tú  Bình Hưng Hòa B  Bình Tân
# Data length:  18
#
# Linear Regression Model:
# Linear Regression training model score:  -0.5902766966700881
#
#
#
#        post_type   area  price street           ward  district
# 0  Bán nhà riêng   48.0   5.30   Số 5  Bình Hưng Hòa  Bình Tân
# 1  Bán nhà riêng   48.0   5.60   Số 5  Bình Hưng Hòa  Bình Tân
# 2  Bán nhà riêng  160.0  10.50   Số 5  Bình Hưng Hòa  Bình Tân
# 3  Bán nhà riêng   50.0   5.40   Số 5  Bình Hưng Hòa  Bình Tân
# 4  Bán nhà riêng  120.0   8.75   Số 5  Bình Hưng Hòa  Bình Tân
# Data length:  21
#
# Linear Regression Model:
# Linear Regression training model score:  0.2664177798808346
#
#
#
#        post_type  area  price street             ward  district
# 0  Bán nhà riêng  60.0   4.25   Số 6  Bình Hưng Hòa B  Bình Tân
# 1  Bán nhà riêng  60.0   4.60   Số 6  Bình Hưng Hòa B  Bình Tân
# 2  Bán nhà riêng  60.0   4.60   Số 6  Bình Hưng Hòa B  Bình Tân
# 3  Bán nhà riêng  32.0   2.40   Số 6  Bình Hưng Hòa B  Bình Tân
# 4  Bán nhà riêng  60.0   4.60   Số 6  Bình Hưng Hòa B  Bình Tân
# Data length:  17
#
# Linear Regression Model:
# Linear Regression training model score:  0.3381863736069358
#
#
#
#        post_type  area  price        street           ward  district
# 0  Bán nhà riêng  54.0   5.20  Tân Hòa Đông  Bình Trị Đông  Bình Tân
# 1  Bán nhà riêng  48.4   5.35  Tân Hòa Đông  Bình Trị Đông  Bình Tân
# 2  Bán nhà riêng  68.0   6.15  Tân Hòa Đông  Bình Trị Đông  Bình Tân
# 3  Bán nhà riêng  64.0   6.20  Tân Hòa Đông  Bình Trị Đông  Bình Tân
# 4  Bán nhà riêng  24.0   2.80  Tân Hòa Đông  Bình Trị Đông  Bình Tân
# Data length:  17
#
# Linear Regression Model:
# Linear Regression training model score:  -0.2613917167556017
#
#
#
#        post_type  area  price   street             ward  district
# 0  Bán nhà riêng  55.0   3.65  Tây Lân  Bình Trị Đông A  Bình Tân
# 1  Bán nhà riêng  60.0   3.66  Tây Lân  Bình Trị Đông A  Bình Tân
# 2  Bán nhà riêng  58.0   3.98  Tây Lân  Bình Trị Đông A  Bình Tân
# 3  Bán nhà riêng  60.0   4.13  Tây Lân  Bình Trị Đông A  Bình Tân
# 4  Bán nhà riêng  84.0   4.30  Tây Lân  Bình Trị Đông A  Bình Tân
# Data length:  21
#
# Linear Regression Model:
# Linear Regression training model score:  -1.0819860386570141
#
#
#
#        post_type  area  price      street           ward  district
# 0  Bán nhà riêng  50.8   4.45  Tỉnh Lộ 10  Bình Trị Đông  Bình Tân
# 1  Bán nhà riêng  40.0   1.58  Tỉnh Lộ 10  Bình Trị Đông  Bình Tân
# 2  Bán nhà riêng  58.0   3.78  Tỉnh Lộ 10  Bình Trị Đông  Bình Tân
# 3  Bán nhà riêng  40.0   2.56  Tỉnh Lộ 10  Bình Trị Đông  Bình Tân
# 4  Bán nhà riêng  52.0   4.20  Tỉnh Lộ 10  Bình Trị Đông  Bình Tân
# Data length:  12
#
# Linear Regression Model:
# Linear Regression training model score:  0.4319867627650199

# %%
import psycopg2
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model


# convert to array:
# area = np.array(data['area'])
# price = np.array(data['price'])
# plt.scatter(area, price, marker='o')
# plt.show()

# Database Connection:
conn = psycopg2.connect(database="real_estate_data", user="postgres", password="361975Warcraft")
cur = conn.cursor()

def getData(post_type, street, ward, district, conn):
    # cur = conn.cursor()
    query = """
        SELECT post_type, area, price, street, ward, district
        FROM bds_realestatedata 
        WHERE
            post_type = '{post_type}' AND
            area IS NOT NULL AND
            price IS NOT NULL AND
            street = '{street}' AND
            ward = '{ward}' AND
            district = '{district}';
    """.format(post_type=post_type, street=street, ward=ward, district=district)
    # cur.execute(query)
    # data = cur.fetchall()
    data = pd.read_sql_query(query, con=conn)

    # data info
    print(data.head())
    print("Data length: ", len(data))
    return data

def splitData(data):
    # Selection few attributes
    attributes = list(
        [
            'area',
        ]
    )
    
    # Vector attributes of lands
    X = data[attributes]
    # Vector price of land
    Y = data['price']
    
    # Convert into arr:
    X = np.array(X)
    Y = np.array(Y)
    
    # plt.plot(Y)
    # plt.show()
    
    # Split data to training test and testing test
    # training data : testing data = 80 : 20
    X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
    
    return X_train, X_test, Y_train, Y_test

# Linear Regression Model:
def linearRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.LinearRegression()

    # Training process
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLinear Regression Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()
    
    score_trained = model.score(X_test, Y_test)

    return score_trained

# Lasso Model:
def lassoRegressionModel(X_train, Y_train, X_test, Y_test):
    model = linear_model.Lasso(alpha=1.0)

    # Training process:
    model.fit(X_train, Y_train)
    
    # Evaluating the model
    print("\nLasso Model:")
    yfit = model.predict(X_test)
    plt.scatter(X_train, Y_train, marker='o')
    plt.plot(X_test, yfit)
    plt.show()

    # Evaluation the model:
    score_trained = model.score(X_test, Y_test)
    
    return score_trained

# Lands:
print("------------------------------")
print("Model Evaluation for Lands")
print("------------------------------")

cur.execute("SELECT post_type, street, ward, district, COUNT(id) FROM bds_realestatedata WHERE street IS NOT NULL AND ward IS NOT NULL AND district = %s AND post_type = %s GROUP BY post_type, street, ward, district HAVING COUNT(id) > %s;", ( 'Bình Tân', 'Bán đất', 10 ) )
item_lst = cur.fetchall()

for item in item_lst:
    post_type = item[0]
    street = item[1]
    ward = item[2]
    district = item[3]
    print("\n")
    data = getData(post_type, street, ward, district, conn)
    X_train, X_test, Y_train, Y_test = splitData(data)

    score = linearRegressionModel(X_train, Y_train, X_test, Y_test)
    print("Linear Regression training model score: ", score, "\n")

# Close connection:
cur.close()
conn.close()
# Out:
# ------------------------------
# Model Evaluation for Lands
# ------------------------------
#
#
#   post_type   area  price street     ward  district
# 0   Bán đất   85.0   3.95      7  Tân Tạo  Bình Tân
# 1   Bán đất   85.0   3.95      7  Tân Tạo  Bình Tân
# 2   Bán đất   96.0   3.10      7  Tân Tạo  Bình Tân
# 3   Bán đất  102.5   3.30      7  Tân Tạo  Bình Tân
# 4   Bán đất   82.0   3.95      7  Tân Tạo  Bình Tân
# Data length:  18
#
# Linear Regression Model:
# Linear Regression training model score:  -6.045272604703148
#
#
#
#   post_type    area   price          street    ward  district
# 0   Bán đất    96.0   6.000  An Dương Vương  An Lạc  Bình Tân
# 1   Bán đất  1117.0  80.424  An Dương Vương  An Lạc  Bình Tân
# 2   Bán đất    63.0   4.500  An Dương Vương  An Lạc  Bình Tân
# 3   Bán đất  1117.0  84.892  An Dương Vương  An Lạc  Bình Tân
# 4   Bán đất  1448.0  80.000  An Dương Vương  An Lạc  Bình Tân
# Data length:  18
#
# Linear Regression Model:
# Linear Regression training model score:  0.9478637329185631
#
#
#
#   post_type   area  price      street             ward  district
# 0   Bán đất   60.0   3.50  Bình Thành  Bình Hưng Hòa B  Bình Tân
# 1   Bán đất  264.0   9.24  Bình Thành  Bình Hưng Hòa B  Bình Tân
# 2   Bán đất  100.0   1.95  Bình Thành  Bình Hưng Hòa B  Bình Tân
# 3   Bán đất   56.0   2.70  Bình Thành  Bình Hưng Hòa B  Bình Tân
# 4   Bán đất  114.0   8.80  Bình Thành  Bình Hưng Hòa B  Bình Tân
# Data length:  28
#
# Linear Regression Model:
# Linear Regression training model score:  0.08157233634049776
#
#
#
#   post_type   area  price      street    ward  district
# 0   Bán đất  110.0   3.30  Hồ Học Lãm  An Lạc  Bình Tân
# 1   Bán đất   90.0   1.80  Hồ Học Lãm  An Lạc  Bình Tân
# 2   Bán đất   84.0   4.95  Hồ Học Lãm  An Lạc  Bình Tân
# 3   Bán đất   80.0   1.70  Hồ Học Lãm  An Lạc  Bình Tân
# 4   Bán đất   90.0   3.20  Hồ Học Lãm  An Lạc  Bình Tân
# Data length:  12
#
# Linear Regression Model:
# Linear Regression training model score:  -6.4940944967110195
#
#
#
#   post_type  area  price       street     ward  district
# 0   Bán đất  64.0   3.20  Hồ Văn Long  Tân Tạo  Bình Tân
# 1   Bán đất  50.3   3.10  Hồ Văn Long  Tân Tạo  Bình Tân
# 2   Bán đất  60.0   2.73  Hồ Văn Long  Tân Tạo  Bình Tân
# 3   Bán đất  64.0   3.20  Hồ Văn Long  Tân Tạo  Bình Tân
# 4   Bán đất  64.0   3.20  Hồ Văn Long  Tân Tạo  Bình Tân
# Data length:  15
#
# Linear Regression Model:
# Linear Regression training model score:  -0.36097571568404985
#
#
#
#   post_type   area  price      street             ward  district
# 0   Bán đất   85.0   4.60  Hương lộ 2  Bình Trị Đông A  Bình Tân
# 1   Bán đất   68.4   4.95  Hương lộ 2  Bình Trị Đông A  Bình Tân
# 2   Bán đất  174.3   3.70  Hương lộ 2  Bình Trị Đông A  Bình Tân
# 3   Bán đất   68.4   4.95  Hương lộ 2  Bình Trị Đông A  Bình Tân
# 4   Bán đất   67.0   4.95  Hương lộ 2  Bình Trị Đông A  Bình Tân
# Data length:  41
#
# Linear Regression Model:
# Linear Regression training model score:  -9.128117845314355
#
#
#
#   post_type   area    price            street    ward  district
# 0   Bán đất   67.5  5.94000  Kinh Dương Vương  An Lạc  Bình Tân
# 1   Bán đất  128.0  7.30000  Kinh Dương Vương  An Lạc  Bình Tân
# 2   Bán đất   51.0  4.58949  Kinh Dương Vương  An Lạc  Bình Tân
# 3   Bán đất   51.0  4.58949  Kinh Dương Vương  An Lạc  Bình Tân
# 4   Bán đất   50.0  4.50000  Kinh Dương Vương  An Lạc  Bình Tân
# Data length:  38
#
# Linear Regression Model:
# Linear Regression training model score:  0.2085063456381644
#
#
#
#   post_type   area  price street    ward  district
# 0   Bán đất  100.0   2.60  Lê Cơ  An Lạc  Bình Tân
# 1   Bán đất  100.0   1.50  Lê Cơ  An Lạc  Bình Tân
# 2   Bán đất   80.0   1.60  Lê Cơ  An Lạc  Bình Tân
# 3   Bán đất   81.0   3.59  Lê Cơ  An Lạc  Bình Tân
# 4   Bán đất   64.0   1.80  Lê Cơ  An Lạc  Bình Tân
# Data length:  21
#
# Linear Regression Model:
# Linear Regression training model score:  -0.1610665956560946
#
#
#
#   post_type  area  price       street             ward  district
# 0   Bán đất  92.0   5.55  Lê Văn Quới  Bình Hưng Hòa A  Bình Tân
# 1   Bán đất  80.0   5.50  Lê Văn Quới  Bình Hưng Hòa A  Bình Tân
# 2   Bán đất  92.0   3.90  Lê Văn Quới  Bình Hưng Hòa A  Bình Tân
# 3   Bán đất  60.0   5.50  Lê Văn Quới  Bình Hưng Hòa A  Bình Tân
# 4   Bán đất  65.0   4.50  Lê Văn Quới  Bình Hưng Hòa A  Bình Tân
# Data length:  28
#
# Linear Regression Model:
# Linear Regression training model score:  -0.69141890888363
#
#
#
#   post_type   area   price       street             ward  district
# 0   Bán đất  176.0  12.000  Lê Văn Quới  Bình Trị Đông A  Bình Tân
# 1   Bán đất  100.0  16.800  Lê Văn Quới  Bình Trị Đông A  Bình Tân
# 2   Bán đất  100.0   3.221  Lê Văn Quới  Bình Trị Đông A  Bình Tân
# 3   Bán đất   72.0   5.400  Lê Văn Quới  Bình Trị Đông A  Bình Tân
# 4   Bán đất   74.0   4.200  Lê Văn Quới  Bình Trị Đông A  Bình Tân
# Data length:  19
#
# Linear Regression Model:
# Linear Regression training model score:  0.8310752081518928
#
#
#
#   post_type   area  price        street             ward  district
# 0   Bán đất   68.0   3.15  Liên khu 4-5  Bình Hưng Hòa B  Bình Tân
# 1   Bán đất  253.0  11.20  Liên khu 4-5  Bình Hưng Hòa B  Bình Tân
# 2   Bán đất   50.0   2.60  Liên khu 4-5  Bình Hưng Hòa B  Bình Tân
# 3   Bán đất   88.0   1.65  Liên khu 4-5  Bình Hưng Hòa B  Bình Tân
# 4   Bán đất  700.0  32.00  Liên khu 4-5  Bình Hưng Hòa B  Bình Tân
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  0.9955598522027646
#
#
#
#   post_type   area  price         street             ward  district
# 0   Bán đất   80.0   1.60  Nguyễn Thị Tú  Bình Hưng Hòa B  Bình Tân
# 1   Bán đất   90.0   2.25  Nguyễn Thị Tú  Bình Hưng Hòa B  Bình Tân
# 2   Bán đất  110.0   4.85  Nguyễn Thị Tú  Bình Hưng Hòa B  Bình Tân
# 3   Bán đất   96.0   3.00  Nguyễn Thị Tú  Bình Hưng Hòa B  Bình Tân
# 4   Bán đất   64.0   3.70  Nguyễn Thị Tú  Bình Hưng Hòa B  Bình Tân
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  -4.135855876790057
#
#
#
#   post_type   area  price           street           ward  district
# 0   Bán đất   82.0   2.85  Phạm Đăng Giảng  Bình Hưng Hòa  Bình Tân
# 1   Bán đất  100.0   1.80  Phạm Đăng Giảng  Bình Hưng Hòa  Bình Tân
# 2   Bán đất  100.0   1.60  Phạm Đăng Giảng  Bình Hưng Hòa  Bình Tân
# 3   Bán đất   52.0   3.35  Phạm Đăng Giảng  Bình Hưng Hòa  Bình Tân
# 4   Bán đất   59.7   3.30  Phạm Đăng Giảng  Bình Hưng Hòa  Bình Tân
# Data length:  11
#
# Linear Regression Model:
# Linear Regression training model score:  -0.42365538880898845
#
#
#
#   post_type   area  price street             ward  district
# 0   Bán đất  100.0  13.00   Số 1  Bình Trị Đông B  Bình Tân
# 1   Bán đất   85.0   2.72   Số 1  Bình Trị Đông B  Bình Tân
# 2   Bán đất  100.0   3.20   Số 1  Bình Trị Đông B  Bình Tân
# 3   Bán đất   90.0   2.90   Số 1  Bình Trị Đông B  Bình Tân
# 4   Bán đất   80.0  13.00   Số 1  Bình Trị Đông B  Bình Tân
# Data length:  14
#
# Linear Regression Model:
# Linear Regression training model score:  -817.9372691045252
#
#
#
#   post_type  area  price street           ward  district
# 0   Bán đất  57.0    3.5   Số 7  Bình Hưng Hòa  Bình Tân
# 1   Bán đất  57.0    3.5   Số 7  Bình Hưng Hòa  Bình Tân
# 2   Bán đất  80.0    1.5   Số 7  Bình Hưng Hòa  Bình Tân
# 3   Bán đất  65.0    4.0   Số 7  Bình Hưng Hòa  Bình Tân
# 4   Bán đất  57.0    3.5   Số 7  Bình Hưng Hòa  Bình Tân
# Data length:  15
#
# Linear Regression Model:
# Linear Regression training model score:  -55.88811252681543
#
#
#
#   post_type   area  price street             ward  district
# 0   Bán đất   85.0   2.72   Số 7  Bình Trị Đông B  Bình Tân
# 1   Bán đất   85.0   3.90   Số 7  Bình Trị Đông B  Bình Tân
# 2   Bán đất   85.0   6.80   Số 7  Bình Trị Đông B  Bình Tân
# 3   Bán đất  100.0   3.20   Số 7  Bình Trị Đông B  Bình Tân
# 4   Bán đất  100.0   3.30   Số 7  Bình Trị Đông B  Bình Tân
# Data length:  32
#
# Linear Regression Model:
# Linear Regression training model score:  0.14011030776709577
#
#
#
#   post_type   area  price street     ward  district
# 0   Bán đất   82.0  3.950   Số 7  Tân Tạo  Bình Tân
# 1   Bán đất  130.0  4.200   Số 7  Tân Tạo  Bình Tân
# 2   Bán đất   85.0  2.900   Số 7  Tân Tạo  Bình Tân
# 3   Bán đất  280.0  8.960   Số 7  Tân Tạo  Bình Tân
# 4   Bán đất   80.0  4.053   Số 7  Tân Tạo  Bình Tân
# Data length:  27
#
# Linear Regression Model:
# Linear Regression training model score:  0.2898783010633764
#
#
#
#   post_type   area  price          street           ward  district
# 0   Bán đất   90.0   1.60  Tân Kỳ Tân Quý  Bình Hưng Hòa  Bình Tân
# 1   Bán đất  100.0   5.85  Tân Kỳ Tân Quý  Bình Hưng Hòa  Bình Tân
# 2   Bán đất   50.0   3.35  Tân Kỳ Tân Quý  Bình Hưng Hòa  Bình Tân
# 3   Bán đất   60.0   4.20  Tân Kỳ Tân Quý  Bình Hưng Hòa  Bình Tân
# 4   Bán đất   53.0   3.36  Tân Kỳ Tân Quý  Bình Hưng Hòa  Bình Tân
# Data length:  18
#
# Linear Regression Model:
# Linear Regression training model score:  0.9723475751859253
#
#
#
#   post_type   area  price   street             ward  district
# 0   Bán đất   64.0   2.85  Tây Lân  Bình Trị Đông A  Bình Tân
# 1   Bán đất   68.0   2.80  Tây Lân  Bình Trị Đông A  Bình Tân
# 2   Bán đất   72.0   3.25  Tây Lân  Bình Trị Đông A  Bình Tân
# 3   Bán đất   60.0   3.00  Tây Lân  Bình Trị Đông A  Bình Tân
# 4   Bán đất  182.0   6.90  Tây Lân  Bình Trị Đông A  Bình Tân
# Data length:  12
#
# Linear Regression Model:
# Linear Regression training model score:  -5.236704459193217
#
#
#
#   post_type   area  price   street             ward  district
# 0   Bán đất   80.0   2.20  Tên Lửa  Bình Trị Đông B  Bình Tân
# 1   Bán đất   79.0   8.49  Tên Lửa  Bình Trị Đông B  Bình Tân
# 2   Bán đất   85.0   2.80  Tên Lửa  Bình Trị Đông B  Bình Tân
# 3   Bán đất  100.0   1.20  Tên Lửa  Bình Trị Đông B  Bình Tân
# 4   Bán đất  100.0   3.50  Tên Lửa  Bình Trị Đông B  Bình Tân
# Data length:  25
#
# Linear Regression Model:
# Linear Regression training model score:  -0.09739817024654851
#
#
#
#   post_type   area  price      street     ward  district
# 0   Bán đất   84.0  3.750  Tỉnh Lộ 10  Tân Tạo  Bình Tân
# 1   Bán đất   84.0  4.000  Tỉnh Lộ 10  Tân Tạo  Bình Tân
# 2   Bán đất   82.0  4.143  Tỉnh Lộ 10  Tân Tạo  Bình Tân
# 3   Bán đất   84.0  4.000  Tỉnh Lộ 10  Tân Tạo  Bình Tân
# 4   Bán đất  123.0  4.200  Tỉnh Lộ 10  Tân Tạo  Bình Tân
# Data length:  23
#
# Linear Regression Model:
# Linear Regression training model score:  -0.6871720381016881
#
#
#
#   post_type   area  price         street     ward  district
# 0   Bán đất   90.0   6.40  Trần Văn Giàu  Tân Tạo  Bình Tân
# 1   Bán đất   90.0   3.50  Trần Văn Giàu  Tân Tạo  Bình Tân
# 2   Bán đất   85.0   3.95  Trần Văn Giàu  Tân Tạo  Bình Tân
# 3   Bán đất  100.0   3.20  Trần Văn Giàu  Tân Tạo  Bình Tân
# 4   Bán đất   85.0   3.80  Trần Văn Giàu  Tân Tạo  Bình Tân
# Data length:  37
#
# Linear Regression Model:
# Linear Regression training model score:  0.46477366112587915
#
#
#
#   post_type   area  price         street       ward  district
# 0   Bán đất   83.0   3.39  Trần Văn Giàu  Tân Tạo A  Bình Tân
# 1   Bán đất  128.0   4.10  Trần Văn Giàu  Tân Tạo A  Bình Tân
# 2   Bán đất   89.0   3.00  Trần Văn Giàu  Tân Tạo A  Bình Tân
# 3   Bán đất   90.0   3.00  Trần Văn Giàu  Tân Tạo A  Bình Tân
# 4   Bán đất   85.0   3.20  Trần Văn Giàu  Tân Tạo A  Bình Tân
# Data length:  13
#
# Linear Regression Model:
# Linear Regression training model score:  -0.43865379613387123
#
#
#
#   post_type   area    price       street    ward  district
# 0   Bán đất   90.0  12.0000  Võ Văn Kiệt  An Lạc  Bình Tân
# 1   Bán đất   90.0   3.2000  Võ Văn Kiệt  An Lạc  Bình Tân
# 2   Bán đất   76.5   4.0545  Võ Văn Kiệt  An Lạc  Bình Tân
# 3   Bán đất   90.0   6.8000  Võ Văn Kiệt  An Lạc  Bình Tân
# 4   Bán đất  180.0  24.0000  Võ Văn Kiệt  An Lạc  Bình Tân
# Data length:  14
#
# Linear Regression Model:
# Linear Regression training model score:  0.6710863198507153
